# %%
import pandas as pd

# %%
data= pd.read_excel("../Datasets-main/ESD.xlsx")
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
gp= data.groupby("Department").agg({"Gender":"count"})
gp
# Out:
#                  Gender
# Department
# Accounting           96
# Engineering         158
# Finance             120
# Human Resources     125
# IT                  241
# Marketing           120
# Sales               140

# %%
gp= data.groupby("Job Title").agg({"Gender":"count"})
gp
# Out:
#                                 Gender
# Job Title
# Account Representative              21
# Analyst                             51
# Analyst II                          53
# Automation Engineer                  7
# Business Partner                    19
# Cloud Infrastructure Architect      15
# Computer Systems Manager            21
# Controls Engineer                   15
# Development Engineer                19
# Director                           121
# Engineering Manager                 20
# Enterprise Architect                18
# Field Engineer                      21
# HRIS Analyst                        16
# IT Coordinator                      11
# IT Systems Architect                12
# Manager                             98
# Network Administrator               10
# Network Architect                   18
# Network Engineer                     7
# Operations Engineer                 12
# Quality Engineer                    20
# Service Desk Analyst                10
# ...

# %%
gp= data.groupby("Department").agg({"EEID":"count"})
gp
# Out:
#                  EEID
# Department
# Accounting         96
# Engineering       158
# Finance           120
# Human Resources   125
# IT                241
# Marketing         120
# Sales             140

# %%
gp= data.groupby(["Department","Gender"]).agg({"EEID":"count"})
gp
# Out:
#                         EEID
# Department      Gender
# Accounting      Female    53
#                 Male      43
# Engineering     Female    80
#                 Male      78
# Finance         Female    69
#                 Male      51
# Human Resources Female    64
#                 Male      61
# IT              Female   119
#                 Male     122
# Marketing       Female    57
#                 Male      63
# Sales           Female    76
#                 Male      64

# %%
gp= data.groupby("Country").agg({"Age":"mean"})
gp
# Out:
#                      Age
# Country
# Brazil         43.654676
# China          45.389908
# United States  44.197512

# %%
gp= data.groupby("Country").agg({"Annual Salary":"max"})
gp
# Out:
#                Annual Salary
# Country
# Brazil                258426
# China                 257194
# United States         258498

# %%
gp= data.groupby("Country").agg({"Annual Salary":"mean"})
gp
# Out:
#                Annual Salary
# Country
# Brazil         112324.834532
# China          113823.532110
# United States  113204.794712

# %%
gp= data.groupby(["Country","Gender"]).agg({"Annual Salary":"max"})
gp
# Out:
#                       Annual Salary
# Country       Gender
# Brazil        Female         258426
#               Male           249506
# China         Female         249686
#               Male           257194
# United States Female         258498
#               Male           258081

# %%
gp= data.groupby(["Country","Gender"]).agg({"EEID":"count"})
gp
# Out:
#                       EEID
# Country       Gender
# Brazil        Female    75
#               Male      64
# China         Female   109
#               Male     109
# United States Female   334
#               Male     309

# %%
gp= data.groupby(["Country","Gender"]).agg({"EEID":"count", "Annual Salary":"max","Age":"mean"})
gp
# Out:
#                       EEID  Annual Salary        Age
# Country       Gender
# Brazil        Female    75         258426  42.240000
#               Male      64         249506  45.312500
# China         Female   109         249686  44.752294
#               Male     109         257194  46.027523
# United States Female   334         258498  44.580838
#               Male     309         258081  43.783172
