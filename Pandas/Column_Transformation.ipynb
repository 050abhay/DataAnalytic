# %% [markdown]
# # Creating a New column from existing column

# %%
import pandas as pd

# %%
data= pd.read_excel("../Datasets-main/ESD.xlsx")
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %% [markdown]
# Creatin a new column from existing condition

# %%
#Creatin a new column from existing condition
data.loc[(data['Bonus %'] == 0) , 'GetBouns'] = "No Bonus"
data.loc[(data['Bonus %'] > 0) , 'GetBouns'] = "Bonus"
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data2= pd.read_excel("../Datasets-main/practice_1.xlsx")
data2
# Out:
#   First Name  Last Name  Salary EEID
# 0       ross  tribbiani   20000   E1
# 1     rachel       bing   40000   E2
# 2     monica      green   25000   E7
# 3       joey     geller   60000   E8
# 4   chandler     buffay   33000   E4
# 5     phoebe       bing   45000   E5

# %%
data2["Full_Name"]= data2["First Name"]+ " "+data2["Last Name"]
data2
# Out:
#   First Name  Last Name  Salary EEID        Full_Name
# 0       ross  tribbiani   20000   E1   ross tribbiani
# 1     rachel       bing   40000   E2      rachel bing
# 2     monica      green   25000   E7     monica green
# 3       joey     geller   60000   E8      joey geller
# 4   chandler     buffay   33000   E4  chandler buffay
# 5     phoebe       bing   45000   E5      phoebe bing

# %%
data2["Full_Name"]= data2["First Name"].str.capitalize()+ " "+data2["Last Name"].str.capitalize()
data2
# Out:
#   First Name  Last Name  Salary EEID        Full_Name
# 0       ross  tribbiani   20000   E1   Ross Tribbiani
# 1     rachel       bing   40000   E2      Rachel Bing
# 2     monica      green   25000   E7     Monica Green
# 3       joey     geller   60000   E8      Joey Geller
# 4   chandler     buffay   33000   E4  Chandler Buffay
# 5     phoebe       bing   45000   E5      Phoebe Bing

# %%
data2["Bonus"]=(data2["Salary"]/100)*20
data2
# Out:
#   First Name  Last Name  Salary EEID        Full_Name    Bonus
# 0       ross  tribbiani   20000   E1   Ross Tribbiani   4000.0
# 1     rachel       bing   40000   E2      Rachel Bing   8000.0
# 2     monica      green   25000   E7     Monica Green   5000.0
# 3       joey     geller   60000   E8      Joey Geller  12000.0
# 4   chandler     buffay   33000   E4  Chandler Buffay   6600.0
# 5     phoebe       bing   45000   E5      Phoebe Bing   9000.0

# %%
data3 = {"Months": ["January", "February", "March", "April"]}
a = pd.DataFrame(data3)
a
# Out:
#      Months
# 0   January
# 1  February
# 2     March
# 3     April

# %%
def extract(value):
    return value[0:3]

a["Short_months"] = a["Months"].map(extract)
print(a)
# Out:
#      Months Short_months
# 0   January          Jan
# 1  February          Feb
# 2     March          Mar
# 3     April          Apr
