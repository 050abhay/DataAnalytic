# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Creating a line plot
plt.plot(x, y)

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')

# Displaying the plot
plt.show()
##This code will generate a simple line plot showing a linear relationship between x and y.

# %%
import nbformat as nbf

# Create a new notebook object
nb = nbf.v4.new_notebook()


# Content for the notebook
content = [
    # Title of the notebook
    ("markdown", "# Plotting in Matplotlib Overview"),
    
    # Introduction
    ("markdown", "Plotting in Matplotlib is a broad topic due to its versatility and depth. "
                 "Below, I’ll provide a detailed overview of plotting in Matplotlib, "
                 "covering the basics, customization options, types of plots, and more advanced techniques."),
    
    # Section 1: Basic Plotting with pyplot
    ("markdown", "## 1. Basic Plotting with pyplot\n"
                 "Matplotlib’s pyplot module provides a MATLAB-like interface for creating simple plots quickly. "
                 "It’s the most commonly used interface in Matplotlib and is ideal for generating basic plots."),
    
    # Subsection: Basic Line Plot
    ("markdown", "### a. Basic Line Plot\n"
                 "A line plot is one of the most basic types of plots. It is used to visualize the relationship between two variables."),
    ("code", "import matplotlib.pyplot as plt\n"
             "\n"
             "# Data\n"
             "x = [1, 2, 3, 4, 5]\n"
             "y = [10, 20, 25, 30, 35]\n"
             "\n"
             "# Creating a line plot\n"
             "plt.plot(x, y)\n"
             "\n"
             "# Adding labels and title\n"
             "plt.xlabel('X-axis Label')\n"
             "plt.ylabel('Y-axis Label')\n"
             "plt.title('Basic Line Plot')\n"
             "\n"
             "# Display the plot\n"
             "plt.show()"),
    
    # Subsection: Plotting Multiple Lines
    ("markdown", "### b. Plotting Multiple Lines\n"
                 "You can plot multiple lines on the same graph by calling `plt.plot()` multiple times."),
    ("code", "import matplotlib.pyplot as plt\n"
             "\n"
             "# Data\n"
             "x = [1, 2, 3, 4, 5]\n"
             "y1 = [10, 20, 25, 30, 35]\n"
             "y2 = [15, 25, 30, 35, 40]\n"
             "\n"
             "# Plotting multiple lines\n"
             "plt.plot(x, y1, label='Line 1')\n"
             "plt.plot(x, y2, label='Line 2')\n"
             "\n"
             "# Adding labels, title, and legend\n"
             "plt.xlabel('X-axis Label')\n"
             "plt.ylabel('Y-axis Label')\n"
             "plt.title('Multiple Line Plot')\n"
             "plt.legend()\n"
             "\n"
             "# Display the plot\n"
             "plt.show()"),
    
    # Section 2: Customizing Plots
    ("markdown", "## 2. Customizing Plots\n"
                 "Matplotlib offers extensive customization options, allowing you to modify almost every aspect of the plot."),
    
    # Subsection: Changing Line Styles and Colors
    ("markdown", "### a. Changing Line Styles and Colors\n"
                 "You can customize the appearance of lines using parameters like color, linestyle, and linewidth."),
    ("code", "plt.plot(x, y, color='red', linestyle='--', linewidth=2, marker='o')"),
    
    # Subsection: Adding Labels and Titles
    ("markdown", "### b. Adding Labels and Titles\n"
                 "Labels and titles are essential for making your plots understandable."),
    ("code", "plt.xlabel('X-axis Label')\n"
             "plt.ylabel('Y-axis Label')\n"
             "plt.title('Plot Title')"),
    
    # Subsection: Customizing Axes
    ("markdown", "### c. Customizing Axes\n"
                 "You can control the appearance of axes using `plt.xlim()` and `plt.ylim()` for limits, "
                 "and `plt.xticks()` and `plt.yticks()` for tick marks."),
    ("code", "plt.xlim(0, 6)\n"
             "plt.ylim(0, 40)\n"
             "plt.xticks([1, 2, 3, 4, 5], ['A', 'B', 'C', 'D', 'E'])"),
    
    # Subsection: Adding Legends
    ("markdown", "### d. Adding Legends\n"
                 "Legends are useful for identifying different lines or plots."),
    ("code", "plt.plot(x, y1, label='Line 1')\n"
             "plt.plot(x, y2, label='Line 2')\n"
             "plt.legend(loc='upper left')"),
    
    # Subsection: Annotations
    ("markdown", "### e. Annotations\n"
                 "You can add annotations to highlight specific points on the plot."),
    ("code", "plt.annotate('Max Value', xy=(5, 35), xytext=(3, 35),\n"
             "             arrowprops=dict(facecolor='black', shrink=0.05))"),
    
    # Section 3: Types of Plots
    ("markdown", "## 3. Types of Plots\n"
                 "Matplotlib supports a wide variety of plots, each suited for different types of data and analyses."),
    
    # Subsection: Bar Plots
    ("markdown", "### a. Bar Plots\n"
                 "Bar plots are used to represent categorical data with rectangular bars."),
    ("code", "categories = ['A', 'B', 'C', 'D']\n"
             "values = [3, 7, 2, 5]\n"
             "\n"
             "plt.bar(categories, values)\n"
             "plt.title('Bar Plot')\n"
             "plt.show()"),
    # Horizontal Bar Plot
    ("code", "plt.barh(categories, values)"),
    
    # Subsection: Histograms
    ("markdown", "### b. Histograms\n"
                 "Histograms are used to represent the distribution of numerical data."),
    ("code", "import numpy as np\n"
             "\n"
             "data = np.random.randn(1000)\n"
             "plt.hist(data, bins=30, alpha=0.5, color='blue')\n"
             "plt.title('Histogram')\n"
             "plt.show()"),
    
    # Subsection: Scatter Plots
    ("markdown", "### c. Scatter Plots\n"
                 "Scatter plots are used to visualize the relationship between two continuous variables."),
    ("code", "x = np.random.rand(50)\n"
             "y = np.random.rand(50)\n"
             "\n"
             "plt.scatter(x, y, color='green')\n"
             "plt.title('Scatter Plot')\n"
             "plt.show()"),
    
    # Subsection: Pie Charts
    ("markdown", "### d. Pie Charts\n"
                 "Pie charts represent the proportion of categorical data as slices of a pie."),
    ("code", "labels = ['A', 'B', 'C', 'D']\n"
             "sizes = [15, 30, 45, 10]\n"
             "\n"
             "plt.pie(sizes, labels=labels, autopct='%1.1f%%')\n"
             "plt.title('Pie Chart')\n"
             "plt.show()"),
    
    # Subsection: Box Plots
    ("markdown", "### e. Box Plots\n"
                 "Box plots are used to visualize the distribution of data based on a five-number summary."),
    ("code", "data = [np.random.randn(100) for _ in range(4)]\n"
             "plt.boxplot(data)\n"
             "plt.title('Box Plot')\n"
             "plt.show()"),
    
    # Subsection: Heatmaps
    ("markdown", "### f. Heatmaps\n"
                 "Heatmaps are used to visualize matrix-like data, often used for showing correlations or distributions."),
    ("code", "data = np.random.rand(10, 10)\n"
             "plt.imshow(data, cmap='hot', interpolation='nearest')\n"
             "plt.colorbar()\n"
             "plt.title('Heatmap')\n"
             "plt.show()"),
    
    # Section 4: Advanced Plotting Techniques
    ("markdown", "## 4. Advanced Plotting Techniques"),
    
    # Subsection: Subplots
    ("markdown", "### a. Subplots\n"
                 "You can create multiple plots in the same figure using `plt.subplot()`."),
    ("code", "plt.figure(figsize=(10, 5))\n"
             "\n"
             "# First subplot\n"
             "plt.subplot(1, 2, 1)\n"
             "plt.plot(x, y1)\n"
             "plt.title('Subplot 1')\n"
             "\n"
             "# Second subplot\n"
             "plt.subplot(1, 2, 2)\n"
             "plt.plot(x, y2)\n"
             "plt.title('Subplot 2')\n"
             "\n"
             "plt.tight_layout()\n"
             "plt.show()"),
    
    # Sub
        # Subsection: 3D Plotting
    ("markdown", "### b. 3D Plotting\n"
                 "Matplotlib supports 3D plotting through the `mplot3d` toolkit."),
    ("code", "from mpl_toolkits.mplot3d import Axes3D\n"
             "\n"
             "fig = plt.figure()\n"
             "ax = fig.add_subplot(111, projection='3d')\n"
             "\n"
             "x = np.random.rand(50)\n"
             "y = np.random.rand(50)\n"
             "z = np.random.rand(50)\n"
             "\n"
             "ax.scatter(x, y, z)\n"
             "plt.title('3D Scatter Plot')\n"
             "plt.show()"),
    
    # Subsection: Logarithmic and Other Scales
    ("markdown", "### c. Logarithmic and Other Scales\n"
                 "You can change the scale of the axes to logarithmic, symlog, logit, etc."),
    ("code", "plt.plot(x, y)\n"
             "plt.yscale('log')\n"
             "plt.title('Logarithmic Scale Plot')\n"
             "plt.show()"),
    
    # Subsection: Working with Dates
    ("markdown", "### d. Working with Dates\n"
                 "Matplotlib can handle date-time data using the `dates` module."),
    ("code", "import matplotlib.dates as mdates\n"
             "import datetime\n"
             "\n"
             "dates = [datetime.date(2023, 1, i) for i in range(1, 10)]\n"
             "values = np.random.rand(9)\n"
             "\n"
             "plt.plot(dates, values)\n"
             "plt.gcf().autofmt_xdate()\n"
             "plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))\n"
             "plt.title('Date Plot')\n"
             "plt.show()"),
    
    # Section 5: Styling and Themes
    ("markdown", "## 5. Styling and Themes\n"
                 "Matplotlib allows you to style plots using various pre-defined styles or by creating custom styles."),
    
    # Subsection: Using Built-in Styles
    ("markdown", "### a. Using Built-in Styles"),
    ("code", "plt.style.use('ggplot')\n"
             "plt.plot(x, y)\n"
             "plt.title('Styled Plot')\n"
             "plt.show()"),
    
    # Subsection: Customizing Styles
    ("markdown", "### b. Customizing Styles\n"
                 "You can create your own style by modifying parameters using `plt.rcParams`."),
    ("code", "plt.rcParams['lines.linewidth'] = 2\n"
             "plt.rcParams['lines.color'] = 'r'\n"
             "\n"
             "plt.plot(x, y)\n"
             "plt.title('Custom Styled Plot')\n"
             "plt.show()"),
    
    # Section 6: Saving and Exporting Plots
    ("markdown", "## 6. Saving and Exporting Plots\n"
                 "Matplotlib allows you to save plots in various formats, such as PNG, PDF, SVG, and more."),
    ("code", "plt.plot(x, y)\n"
             "plt.title('Plot to Save')\n"
             "plt.savefig('plot.png', dpi=300, bbox_inches='tight')\n"
             "plt.show()"),
    
    # Section 7: Interactive Plotting
    ("markdown", "## 7. Interactive Plotting\n"
                 "Matplotlib supports interactive plotting, especially in environments like Jupyter Notebooks. "
                 "You can enable interactive mode using:"),
    ("code", "plt.ion()"),
    
    # Section 8: Object-Oriented Interface
    ("markdown", "## 8. Object-Oriented Interface\n"
                 "While `pyplot` is easy for quick plots, Matplotlib also provides an object-oriented interface for more complex and fine-grained control."),
    
    # Subsection: Creating Figures and Axes
    ("markdown", "### a. Creating Figures and Axes"),
    ("code", "fig, ax = plt.subplots()\n"
             "ax.plot(x, y)\n"
             "ax.set_title('Object-Oriented Plot')\n"
             "ax.set_xlabel('X-axis Label')\n"
             "ax.set_ylabel('Y-axis Label')\n"
             "plt.show()"),
    
    # Subsection: Multiple Axes and Layouts
    ("markdown", "### b. Multiple Axes and Layouts\n"
                 "You can create complex layouts with multiple subplots using the object-oriented approach."),
    ("code", "fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))\n"
             "ax1.plot(x, y1)\n"
             "ax1.set_title('Plot 1')\n"
             "ax2.plot(x, y2)\n"
             "ax2.set_title('Plot 2')\n"
             "plt.tight_layout()\n"
             "plt.show()"),
    
    # Summary
    ("markdown", "## Summary\n"
                 "Plotting in Matplotlib is a comprehensive topic with a wide range of functionalities, from simple line plots to complex 3D plots and interactive visualizations. "
                 "The library's flexibility allows for extensive customization, making it suitable for both quick exploratory plots and detailed publication-quality figures. "
                 "Whether using the `pyplot` interface for quick plots or the object-oriented approach for more control, Matplotlib is a powerful tool for all your data visualization needs in Python.")
]

# Add the content to the notebook
for cell_type, cell_content in content:
    if cell_type == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(cell_content))
    elif cell_type == "code":
        nb.cells.append(nbf.v4.new_code_cell(cell_content))

# Write the notebook to a file
with open("Plotting_Overview.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook 'Plotting_Overview.ipynb' created successfully.")
# Out:
# Notebook 'Plotting_Overview.ipynb' created successfully.

# %%
import nbformat as nbf

# Create a new notebook object
nb = nbf.v4.new_notebook()

# Define the content to add to the notebook
content = [
    {
        "cell_type": "markdown",
        "source": (
            "### The `matplotlib.pyplot.bar` function is used to create bar charts in Matplotlib, "
            "which are ideal for visualizing categorical data. A bar chart represents data with "
            "rectangular bars where the length of each bar is proportional to the value it represents. "
            "Bar charts can be either vertical or horizontal, and Matplotlib offers a lot of flexibility "
            "in customizing these plots."
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 1. Basic Usage of `bar` Function"
    },
    {
        "cell_type": "markdown",
        "source": "### a. Creating a Simple Vertical Bar Chart"
    },
    {
        "cell_type": "code",
        "source": (
            "import matplotlib.pyplot as plt\n\n"
            "# Data\n"
            "categories = ['A', 'B', 'C', 'D']\n"
            "values = [3, 7, 2, 5]\n\n"
            "# Create a vertical bar chart\n"
            "plt.bar(categories, values)\n\n"
            "# Adding labels and title\n"
            "plt.xlabel('Categories')\n"
            "plt.ylabel('Values')\n"
            "plt.title('Simple Bar Chart')\n\n"
            "# Display the plot\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 2. Customizing Bars"
    },
    {
        "cell_type": "markdown",
        "source": "### a. Changing Bar Colors"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, color='blue')\n"
            "plt.title('Bar Chart with Custom Colors')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "code",
        "source": (
            "colors = ['red', 'green', 'blue', 'orange']\n"
            "plt.bar(categories, values, color=colors)\n"
            "plt.title('Bar Chart with Different Colors')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "### b. Adding Edge Colors"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, color='lightblue', edgecolor='black')\n"
            "plt.title('Bar Chart with Edge Colors')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "### c. Bar Width"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, width=0.5, color='purple')\n"
            "plt.title('Bar Chart with Custom Bar Width')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 3. Adding Labels and Titles"
    },
    {
        "cell_type": "markdown",
        "source": "### a. Adding X and Y Labels"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, color='skyblue')\n"
            "plt.xlabel('Categories')\n"
            "plt.ylabel('Values')\n"
            "plt.title('Bar Chart Example')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 4. Displaying Values on Bars"
    },
    {
        "cell_type": "code",
        "source": (
            "bars = plt.bar(categories, values, color='skyblue')\n\n"
            "# Adding value labels on top of bars\n"
            "for bar in bars:\n"
            "    yval = bar.get_height()\n"
            "    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom')  # va: vertical alignment\n\n"
            "plt.title('Bar Chart with Value Labels')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 5. Horizontal Bar Chart"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.barh(categories, values, color='lightgreen')\n"
            "plt.xlabel('Values')\n"
            "plt.ylabel('Categories')\n"
            "plt.title('Horizontal Bar Chart')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 6. Grouped and Stacked Bar Charts"
    },
    {
        "cell_type": "markdown",
        "source": "### a. Grouped Bar Chart"
    },
    {
        "cell_type": "code",
        "source": (
            "import numpy as np\n\n"
            "# Data\n"
            "categories = ['A', 'B', 'C', 'D']\n"
            "values1 = [3, 7, 2, 5]\n"
            "values2 = [2, 5, 8, 3]\n\n"
            "# Positioning the bars\n"
            "bar_width = 0.35\n"
            "index = np.arange(len(categories))\n\n"
            "plt.bar(index, values1, bar_width, label='Series 1', color='blue')\n"
            "plt.bar(index + bar_width, values2, bar_width, label='Series 2', color='orange')\n\n"
            "# Adding labels and title\n"
            "plt.xlabel('Categories')\n"
            "plt.ylabel('Values')\n"
            "plt.title('Grouped Bar Chart')\n"
            "plt.xticks(index + bar_width / 2, categories)  # Adjust x-ticks\n"
            "plt.legend()\n\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "### b. Stacked Bar Chart"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values1, color='blue', label='Series 1')\n"
            "plt.bar(categories, values2, color='orange', bottom=values1, label='Series 2')\n\n"
            "# Adding labels and title\n"
            "plt.xlabel('Categories')\n"
            "plt.ylabel('Values')\n"
            "plt.title('Stacked Bar Chart')\n"
            "plt.legend()\n\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 7. Customizing Ticks and Grids"
    },
    {
        "cell_type": "markdown",
        "source": "### a. Customizing Ticks"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, color='coral')\n"
            "plt.xticks(rotation=45)  # Rotate x-ticks\n"
            "plt.title('Bar Chart with Rotated Ticks')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "### b. Adding Grids"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, color='teal')\n"
            "plt.grid(axis='y')  # Add gridlines to the y-axis\n"
            "plt.title('Bar Chart with Gridlines')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 8. Handling Missing Data"
    },
    {
        "cell_type": "code",
        "source": (
            "import numpy as np\n\n"
            "# Data with a missing value\n"
            "values_with_nan = [3, np.nan, 2, 5]\n\n"
            "plt.bar(categories, values_with_nan, color='lightcoral')\n"
            "plt.title('Bar Chart with Missing Data')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 9. Error Bars"
    },
    {
        "cell_type": "code",
        "source": (
            "# Sample data with error bars\n"
            "errors = [0.5, 0.4, 0.6, 0.3]\n\n"
            "plt.bar(categories, values, yerr=errors, capsize=5, color='lightblue')\n"
            "plt.title('Bar Chart with Error Bars')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": "## 10. Saving the Bar Chart"
    },
    {
        "cell_type": "code",
        "source": (
            "plt.bar(categories, values, color='purple')\n"
            "plt.title('Bar Chart to Save')\n"
            "plt.savefig('bar_chart.png', dpi=300, bbox_inches='tight')\n"
            "plt.show()"
        )
    },
    {
        "cell_type": "markdown",
        "source": (
            "### Summary:\n"
            "The `matplotlib.pyplot.bar` function is a powerful and versatile tool for creating bar charts. "
            "It allows you to:\n\n"
            "- Create both vertical and horizontal bar charts.\n"
            "- Customize colors, bar widths, and add labels, titles, and grids.\n"
            "- Display value labels on bars, create grouped and stacked bar charts, and add error bars.\n"
            "- Handle missing data gracefully.\n"
            "- Save the plots in various formats.\n\n"
            "Bar charts are an effective way to visualize categorical data, and Matplotlib provides all the tools needed to create informative and visually appealing charts."
        )
    }
]

# Add cells to the notebook
nb['cells'] = [
    nbf.v4.new_markdown_cell(c['source']) if c['cell_type'] == 'markdown' 
    else nbf.v4.new_code_cell(c['source']) 
    for c in content
]


# Write the notebook to a file
with open("Bar_Charts.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook 'Bar_Charts.ipynb' created successfully.")
# Out:
# Notebook 'Bar_Charts.ipynb' created successfully.

# %%
import nbformat as nbf

# Create a new notebook object
nb = nbf.v4.new_notebook()

# Define the content
content = [
    {"cell_type": "markdown", "source": "# matplotlib.pyplot.plot\n\n"
                                         "The `matplotlib.pyplot.plot` function is one of the most commonly used functions in Matplotlib for creating 2D line plots. "
                                         "It provides a flexible and powerful way to visualize data by connecting points with lines. "
                                         "Below, I’ll discuss the `plot` function in detail, covering its usage, customization options, and advanced features with examples."},

    {"cell_type": "markdown", "source": "## 1. Basic Usage of `plot` Function\n\n"
                                         "The `plot` function is used to create simple line plots. It takes at least one argument for the y-values, "
                                         "but typically, both x and y values are provided."},

    {"cell_type": "markdown", "source": "### a. Simple Line Plot"},
    
    {"cell_type": "code", "source": "import matplotlib.pyplot as plt\n\n"
                                     "# Data\n"
                                     "x = [1, 2, 3, 4, 5]\n"
                                     "y = [2, 4, 6, 8, 10]\n\n"
                                     "# Create a simple line plot\n"
                                     "plt.plot(x, y)\n\n"
                                     "# Adding labels and title\n"
                                     "plt.xlabel('X-axis')\n"
                                     "plt.ylabel('Y-axis')\n"
                                     "plt.title('Simple Line Plot')\n\n"
                                     "# Display the plot\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "In this example:\n"
                                         "- `x` represents the data for the x-axis.\n"
                                         "- `y` represents the data for the y-axis.\n\n"
                                         "The `plot` function connects the points defined by `x` and `y` with a line."},

    {"cell_type": "markdown", "source": "## 2. Plotting Multiple Lines\n\n"
                                         "You can plot multiple lines on the same graph by calling `plt.plot()` multiple times or by passing multiple datasets in a single call."},
    
    {"cell_type": "code", "source": "x = [1, 2, 3, 4, 5]\n"
                                     "y1 = [2, 4, 6, 8, 10]\n"
                                     "y2 = [1, 2, 4, 8, 16]\n\n"
                                     "# Plotting multiple lines\n"
                                     "plt.plot(x, y1, label='y = 2x')\n"
                                     "plt.plot(x, y2, label='y = 2^x')\n\n"
                                     "# Adding labels, title, and legend\n"
                                     "plt.xlabel('X-axis')\n"
                                     "plt.ylabel('Y-axis')\n"
                                     "plt.title('Multiple Line Plot')\n"
                                     "plt.legend()\n\n"
                                     "# Display the plot\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 3. Customizing Line Style, Color, and Markers\n\n"
                                         "Matplotlib allows you to customize the appearance of the lines using parameters such as color, linestyle, and marker."},

    {"cell_type": "markdown", "source": "### a. Changing Line Color\n\n"
                                         "You can change the color of the line using the `color` parameter."},

    {"cell_type": "code", "source": "plt.plot(x, y1, color='red', label='Red Line')\n"
                                     "plt.plot(x, y2, color='green', label='Green Line')\n"
                                     "plt.legend()\n"
                                     "plt.title('Line Plot with Custom Colors')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "### b. Changing Line Style\n\n"
                                         "The `linestyle` parameter controls the style of the line. Common options include:\n"
                                         "- `'-'` (solid line, default)\n"
                                         "- `'--'` (dashed line)\n"
                                         "- `':'` (dotted line)\n"
                                         "- `'-.'` (dash-dot line)"},

    {"cell_type": "code", "source": "plt.plot(x, y1, linestyle='--', color='blue', label='Dashed Line')\n"
                                     "plt.plot(x, y2, linestyle=':', color='orange', label='Dotted Line')\n"
                                     "plt.legend()\n"
                                     "plt.title('Line Plot with Custom Line Styles')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "### c. Adding Markers\n\n"
                                         "Markers highlight the individual data points on the line. Common marker options include:\n"
                                         "- `'o'` (circle)\n"
                                         "- `'s'` (square)\n"
                                         "- `'^'` (triangle)\n"
                                         "- `'D'` (diamond)"},

    {"cell_type": "code", "source": "plt.plot(x, y1, marker='o', color='purple', label='Circle Markers')\n"
                                     "plt.plot(x, y2, marker='s', color='brown', label='Square Markers')\n"
                                     "plt.legend()\n"
                                     "plt.title('Line Plot with Markers')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 4. Combining Line Style, Color, and Marker\n\n"
                                         "You can combine line style, color, and marker in a single string."},

    {"cell_type": "code", "source": "plt.plot(x, y1, 'r--o', label='Red Dashed Line with Circles')  # Red dashed line with circles\n"
                                     "plt.plot(x, y2, 'g-.s', label='Green Dash-Dot Line with Squares')  # Green dash-dot line with squares\n"
                                     "plt.legend()\n"
                                     "plt.title('Combined Line Style, Color, and Marker')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 5. Handling Multiple Lines with Different Styles\n\n"
                                         "You can handle multiple lines with different styles by passing the attributes directly for each line."},

    {"cell_type": "code", "source": "plt.plot(x, y1, linestyle='--', color='blue', marker='o', label='y1 = 2x')\n"
                                     "plt.plot(x, y2, linestyle='-', color='red', marker='s', label='y2 = 2^x')\n"
                                     "plt.legend()\n"
                                     "plt.title('Multiple Lines with Different Styles')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 6. Advanced Plot Customization\n\n"
                                         "### a. Adding Grid Lines\n\n"
                                         "Grid lines make the plot easier to read by aligning the data points with the axes."},

    {"cell_type": "code", "source": "plt.plot(x, y1, 'b-o', label='y1 = 2x')\n"
                                     "plt.plot(x, y2, 'g-^', label='y2 = 2^x')\n"
                                     "plt.grid(True)  # Add grid lines\n"
                                     "plt.xlabel('X-axis')\n"
                                     "plt.ylabel('Y-axis')\n"
                                     "plt.title('Line Plot with Grid Lines')\n"
                                     "plt.legend()\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "### b. Customizing Axes\n\n"
                                         "You can control the limits and ticks of the axes using `plt.xlim()`, `plt.ylim()`, `plt.xticks()`, and `plt.yticks()`."},

    {"cell_type": "code", "source": "plt.plot(x, y1, 'm--o', label='y1 = 2x')\n"
                                     "plt.plot(x, y2, 'c-^', label='y2 = 2^x')\n"
                                     "plt.xlim(0, 6)\n"
                                     "plt.ylim(0, 18)\n"
                                     "plt.xticks([1, 2, 3, 4, 5])\n"
                                     "plt.yticks([0, 4, 8, 12, 16])\n"
                                     "plt.xlabel('X-axis')\n"
                                     "plt.ylabel('Y-axis')\n"
                                     "plt.title('Line Plot with Custom Axes')\n"
                                     "plt.legend()\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "### c. Annotating Points\n\n"
                                         "Annotations help highlight specific data points."},

    {"cell_type": "code", "source": "plt.plot(x, y2, 'r-o', label='y2 = 2^x')\n"
                                     "plt.annotate('Highest Point', xy=(5, 16), xytext=(3, 15),\n"
                                     "             arrowprops=dict(facecolor='black', shrink=0.05))\n"
                                     "plt.xlabel('X-axis')\n"
                                     "plt.ylabel('Y-axis')\n"
                                     "plt.title('Line Plot with Annotation')\n"
                                     "plt.legend()\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 7. Plotting with Logarithmic Scales\n\n"
                                         "You can change the scale of the axes to logarithmic using `plt.xscale()` and `plt.yscale()`."},

    {"cell_type": "code", "source": "plt.plot(x, y2, 'g-o', label='y2 = 2^x')\n"
                                     "plt.yscale('log')\n"
                                     "plt.xlabel('X-axis')\n"
                                     "plt.ylabel('Log Y-axis')\n"
                                     "plt.title('Line Plot with Logarithmic Scale')\n"
                                     "plt.legend()\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 8. Subplots\n\n"
                                         "You can create multiple subplots in a single figure using `plt.subplot()`."},

    {"cell_type": "code", "source": "plt.figure(figsize=(10, 5))\n\n"
                                     "# First subplot\n"
                                     "plt.subplot(1, 2, 1)\n"
                                     "plt.plot(x, y1, 'b-o')\n"
                                     "plt.title('Subplot 1: y = 2x')\n\n"
                                     "# Second subplot\n"
                                     "plt.subplot(1, 2, 2)\n"
                                     "plt.plot(x, y2, 'r-^')\n"
                                     "plt.title('Subplot 2: y = 2^x')\n\n"
                                     "plt.tight_layout()\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 9. Plotting with Date and Time Data\n\n"
                                         "Matplotlib can handle date and time data, making it ideal for time series analysis."},

    {"cell_type": "code", "source": "import matplotlib.dates as mdates\n"
                                     "import datetime\n\n"
                                     "# Sample date data\n"
                                     "dates = [datetime.date(2024, 8, i) for i in range(1, 6)]\n"
                                     "values = [1, 3, 2, 5, 4]\n\n"
                                     "plt.plot(dates, values, 'b-o')\n\n"
                                     "# Formatting the date axis\n"
                                     "plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))\n"
                                     "plt.gca().xaxis.set_major_locator(mdates.DayLocator())\n\n"
                                     "plt.gcf().autofmt_xdate()  # Rotate date labels\n"
                                     "plt.xlabel('Date')\n"
                                     "plt.ylabel('Values')\n"
                                     "plt.title('Line Plot with Date Data')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 10. Saving the Plot\n\n"
                                         "You can save the plot to a file using `plt.savefig()`."},

    {"cell_type": "code", "source": "plt.plot(x, y1, 'b-o')\n"
                                     "plt.title('Plot to Save')\n"
                                     "plt.savefig('line_plot.png', dpi=300, bbox_inches='tight')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## 11. Interactive Plots\n\n"
                                         "In environments like Jupyter Notebooks, you can create interactive plots that allow for dynamic exploration."},

    {"cell_type": "code", "source": "%matplotlib inline  # Use '%matplotlib notebook' for interactive plots\n"
                                     "plt.plot(x, y1, 'g-o')\n"
                                     "plt.title('Interactive Plot Example')\n"
                                     "plt.show()"},

    {"cell_type": "markdown", "source": "## Summary\n\n"
                                         "The `matplotlib.pyplot.plot` function is a fundamental tool in Matplotlib for creating line plots. It offers:\n\n"
                                         "- **Basic Plotting**: Simple line plots by connecting data points with lines.\n"
                                         "- **Customization**: Control over line styles, colors, markers, axes, grids, and annotations.\n"
                                         "- **Advanced Features**: Support for subplots, logarithmic scales, date/time data, and saving plots.\n"
                                         "- **Interactivity**: Integration with environments like Jupyter for interactive exploration.\n\n"
                                         "Whether you need quick exploratory plots or detailed, publication-quality figures, `plot` is an essential function in Matplotlib for visualizing data effectively."}
]

# Add each cell to the notebook
for cell in content:
    if cell["cell_type"] == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(cell["source"]))
    elif cell["cell_type"] == "code":
        nb.cells.append(nbf.v4.new_code_cell(cell["source"]))


    
# Write the notebook to a file
with open("Line_Plot.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook 'Line_Plot.ipynb' created successfully.")
# Out:
# Notebook 'Line_Plot.ipynb' created successfully.

# %%
import nbformat as nbf

# Create a new notebook
nb = nbf.v4.new_notebook()

# Define the content for the markdown and code cells
cells = [
    nbf.v4.new_markdown_cell("""
3. **matplotlib.pyplot.scatter**

The `matplotlib.pyplot.scatter` function is used to create scatter plots in Matplotlib. Scatter plots are a type of plot that shows individual data points on a two-dimensional graph, where the position of each point is determined by two variables. Scatter plots are particularly useful for visualizing the relationship between two continuous variables, identifying trends, clusters, and outliers.
"""),
    nbf.v4.new_markdown_cell("""
1. **Basic Usage of scatter Function**

The scatter function requires two main inputs: the x-values and the y-values. Each pair of x and y values corresponds to a single point on the scatter plot.
"""),
    nbf.v4.new_code_cell("""
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a simple scatter plot
plt.scatter(x, y)

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Scatter Plot')

# Display the plot
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
In this example:
- `x` represents the data for the x-axis.
- `y` represents the data for the y-axis.

The scatter function plots each pair of x and y values as a point on the graph.
"""),
    
    nbf.v4.new_markdown_cell("""
2. **Customizing Markers**

You can customize the appearance of the points (markers) on the scatter plot using parameters such as color, marker, `s` (size), and `alpha` (transparency).
"""),
    nbf.v4.new_markdown_cell("""
a. **Changing Marker Color**

You can change the color of the markers using the `color` parameter.
"""),
    nbf.v4.new_code_cell("""
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Changing Marker Color
plt.scatter(x, y, color='red')
plt.title('Scatter Plot with Red Markers')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
b. **Changing Marker Size**

The `s` parameter controls the size of the markers. You can pass a single value to set a uniform size for all markers, or an array to vary the size based on a third variable.
"""),
    nbf.v4.new_code_cell("""
# Changing Marker Size
plt.scatter(x, y, s=100)  # Larger markers
plt.title('Scatter Plot with Larger Markers')
plt.show()
"""),
    nbf.v4.new_code_cell("""
sizes = [20, 50, 100, 200, 300]  # Variable marker sizes
plt.scatter(x, y, s=sizes)
plt.title('Scatter Plot with Variable Marker Sizes')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
c. **Changing Marker Shape**

The `marker` parameter allows you to change the shape of the markers. Some common options include:
- `'o'` (circle, default)
- `'s'` (square)
- `'^'` (triangle up)
- `'D'` (diamond)
- `'x'` (cross)
"""),
    nbf.v4.new_code_cell("""
# Changing Marker Shape
plt.scatter(x, y, marker='^')  # Triangle markers
plt.title('Scatter Plot with Triangle Markers')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
d. **Adjusting Transparency**

The `alpha` parameter controls the transparency of the markers. A value of 0 is fully transparent, while 1 is fully opaque.
"""),
    nbf.v4.new_code_cell("""
# Adjusting Transparency
plt.scatter(x, y, color='blue', alpha=0.5)  # Semi-transparent markers
plt.title('Scatter Plot with Transparency')
plt.show()
"""),
   nbf.v4.new_markdown_cell("""
3. **Using Different Colors for Points**

You can assign different colors to the points based on a third variable using the `c` parameter.
"""),
    nbf.v4.new_code_cell("""
import matplotlib.pyplot as plt
import numpy as np

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
colors = [10, 20, 30, 40, 50]  # Third variable determining colors

plt.scatter(x, y, c=colors, cmap='viridis')  # Use a colormap
plt.colorbar()  # Show color scale
plt.title('Scatter Plot with Color Mapping')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
In this example:
- `c` parameter is used to specify the colors of the points.
- `cmap` parameter specifies the colormap to use (e.g., 'viridis', 'plasma', 'inferno', 'magma', etc.).
- `plt.colorbar()` adds a color bar to indicate the color mapping.
"""),
    nbf.v4.new_markdown_cell("""
4. **Advanced Scatter Plot Customizations**
"""),
    nbf.v4.new_markdown_cell("""
a. **Combining Marker Size and Color**

You can vary both the size and color of the markers to represent additional dimensions of data.
"""),
    nbf.v4.new_code_cell("""
sizes = [20, 50, 100, 200, 300]
colors = [10, 20, 30, 40, 50]

plt.scatter(x, y, s=sizes, c=colors, cmap='viridis', alpha=0.7)
plt.colorbar()
plt.title('Scatter Plot with Variable Size and Color')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
b. **Adding Labels to Points**

You can annotate individual points on the scatter plot with text labels using `plt.text()`.
"""),
    nbf.v4.new_code_cell("""
plt.scatter(x, y, color='green')

# Adding labels to points
for i, label in enumerate(['A', 'B', 'C', 'D', 'E']):
    plt.text(x[i], y[i], label)

plt.title('Scatter Plot with Labels')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
5. **Scatter Plot with Multiple Data Series**

You can plot multiple datasets on the same scatter plot by calling `plt.scatter()` multiple times.
"""),
    nbf.v4.new_code_cell("""
# Data for two groups
x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]

x2 = [1, 2, 3, 4, 5]
y2 = [3, 6, 9, 12, 15]

# Scatter plot for both groups
plt.scatter(x1, y1, color='blue', label='Group 1')
plt.scatter(x2, y2, color='orange', label='Group 2')

# Adding labels, title, and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Multiple Data Series')
plt.legend()

plt.show()
"""),
    nbf.v4.new_markdown_cell("""
6. **Logarithmic and Other Scales**

You can change the scale of the axes to logarithmic, symlog, or other types using `plt.xscale()` and `plt.yscale()`.
"""),
    nbf.v4.new_code_cell("""
plt.scatter(x, y, color='purple')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Logarithmic X-axis')
plt.ylabel('Logarithmic Y-axis')
plt.title('Scatter Plot with Logarithmic Scales')
plt.show()
"""), 
nbf.v4.new_markdown_cell("""
7. **Handling Large Datasets**

For large datasets, scatter plots can become crowded. Here are some techniques to handle large datasets:
"""),
    nbf.v4.new_markdown_cell("""
a. **Reducing Marker Size and Transparency**

Reducing the marker size and increasing transparency can help visualize dense plots.
"""),
    nbf.v4.new_code_cell("""
import matplotlib.pyplot as plt
import numpy as np

# Data for large dataset
large_x = np.random.rand(1000)
large_y = np.random.rand(1000)

# Reducing Marker Size and Transparency
plt.scatter(large_x, large_y, s=10, alpha=0.3)
plt.title('Scatter Plot for Large Datasets')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
b. **Hexbin Plot**

For very large datasets, consider using a hexbin plot, which aggregates data into hexagonal bins.
"""),
    nbf.v4.new_code_cell("""
# Hexbin Plot
plt.hexbin(large_x, large_y, gridsize=30, cmap='Blues')
plt.colorbar(label='Count')
plt.title('Hexbin Plot for Large Datasets')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
8. **Subplots with Scatter Plots**

You can create multiple scatter plots in a single figure using `plt.subplot()`.
"""),
    nbf.v4.new_code_cell("""
# Subplots with Scatter Plots
plt.figure(figsize=(10, 5))

# First subplot
plt.subplot(1, 2, 1)
plt.scatter(large_x, large_y, color='blue')
plt.title('Scatter Plot 1')

# Second subplot
plt.subplot(1, 2, 2)
plt.scatter(large_y, large_x, color='red')
plt.title('Scatter Plot 2')

plt.tight_layout()
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
9. **Interactive Scatter Plots**

In interactive environments like Jupyter Notebooks, you can create scatter plots that allow for dynamic exploration.
"""),
    nbf.v4.new_code_cell("""
# Interactive Scatter Plot
# %matplotlib notebook
plt.scatter(large_x, large_y, color='green')
plt.title('Interactive Scatter Plot')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
10. **Saving the Scatter Plot**

You can save the scatter plot to a file using `plt.savefig()`.
"""),
    nbf.v4.new_code_cell("""
# Saving the Scatter Plot
plt.scatter(large_x, large_y, color='purple')
plt.title('Scatter Plot to Save')
plt.savefig('scatter_plot.png', dpi=300, bbox_inches='tight')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
11. **3D Scatter Plots**

Matplotlib supports 3D scatter plots through the `mplot3d` toolkit.
"""),
    nbf.v4.new_code_cell("""
from mpl_toolkits.mplot3d import Axes3D

# Data for 3D scatter plot
z = [1, 4, 9, 16, 25]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(large_x[:5], large_y[:5], z, color='teal')

# Adding labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Scatter Plot')

plt.show()
"""),
    nbf.v4.new_markdown_cell("""
**Summary:**

The `matplotlib.pyplot.scatter` function is a powerful tool for creating scatter plots in Matplotlib. It offers:
- **Basic Plotting**: Simple scatter plots to visualize the relationship between two variables.
- **Customization**: Extensive control over marker color, size, shape, and transparency.
- **Advanced Features**: Ability to encode additional dimensions using color and size, annotate points, and handle large datasets.
- **Interactivity**: Support for interactive exploration in environments like Jupyter Notebooks.
- **3D Plotting**: Create 3D scatter plots for visualizing three-dimensional data.

Scatter plots are essential for exploring the relationships, trends, and patterns within data, and Matplotlib’s scatter function provides the flexibility needed to create informative and visually appealing plots.
""")
    
]

# Add cells to the notebook
nb.cells.extend(cells)

# Save the notebook to a .ipynb file
with open('Scatter_Plot.ipynb', 'w', encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook created successfully.")
# Out:
# Notebook created successfully.

# %%
from nbformat import v4 as nbf
import nbformat

# Create a new notebook
nb = nbf.new_notebook()


# Markdown cells
text = """
# matplotlib.pyplot.pie

The `matplotlib.pyplot.pie` function is used to create pie charts in Matplotlib. Pie charts are circular charts divided into sectors, each representing a proportion of the whole. They are particularly useful for visualizing categorical data and showing the relative proportions of different categories.

## 1. Basic Usage of pie Function
The `pie` function requires a sequence of numerical data (which represents the sizes of the pie pieces) and can optionally take other parameters like labels, colors, and explode.

### a. Simple Pie Chart
"""

# Add the first markdown cell
nb.cells.append(nbf.new_markdown_cell(text))

# Code cell 1
code1 = """
import matplotlib.pyplot as plt

# Data
sizes = [25, 35, 20, 20]
labels = ['Category A', 'Category B', 'Category C', 'Category D']

# Create a simple pie chart
plt.pie(sizes, labels=labels)

# Adding a title
plt.title('Simple Pie Chart')

# Display the plot
plt.show()
"""
nb.cells.append(nbf.new_code_cell(code1))

# Markdown cell 2
text2 = """
In this example:

- `sizes` represents the size of each pie piece.
- `labels` represents the categories for each slice.

The `pie` function automatically calculates the proportions of each slice based on the sizes provided.

## 2. Customizing the Pie Chart
Matplotlib provides several options to customize the appearance of pie charts, including colors, explode effects, start angles, and more.

### a. Customizing Colors
You can customize the colors of the pie slices by passing a `colors` list.
"""

nb.cells.append(nbf.new_markdown_cell(text2))

# Code cell 2
code2 = """
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors)
plt.title('Pie Chart with Custom Colors')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code2))

# Markdown cell 3
text3 = """
### b. Adding Explode Effect
The `explode` parameter allows you to "explode" or offset a slice from the pie chart for emphasis. This can be useful to highlight a specific category.
"""

nb.cells.append(nbf.new_markdown_cell(text3))

# Code cell 3
code3 = """
explode = (0, 0.1, 0, 0)  # Explode the second slice (i.e., 'Category B')

plt.pie(sizes, labels=labels, colors=colors, explode=explode)
plt.title('Pie Chart with Explode Effect')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code3))

# Markdown cell 4
text4 = """
In this example, the second slice (Category B) is exploded outwards to draw attention to it.

### c. Starting Angle
The `startangle` parameter rotates the start of the pie chart by the given angle, which can help improve readability by positioning slices in a more intuitive way.
"""

nb.cells.append(nbf.new_markdown_cell(text4))

# Code cell 4
code4 = """
plt.pie(sizes, labels=labels, colors=colors, startangle=90)
plt.title('Pie Chart with Start Angle')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code4))

# Markdown cell 5
text5 = """
## 3. Displaying Percentages
You can display the percentage of the total for each slice by using the `autopct` parameter.
"""

nb.cells.append(nbf.new_markdown_cell(text5))

# Code cell 5
code5 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Pie Chart with Percentages')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code5))

# Markdown cell 6
text6 = """
In this example, the `autopct` parameter is set to `'%1.1f%%'`, which formats the percentages to one decimal place.

## 4. Adding Shadows
The `shadow` parameter adds a shadow effect to the pie chart, giving it a 3D appearance.
"""

nb.cells.append(nbf.new_markdown_cell(text6))

# Code cell 6
code6 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.title('Pie Chart with Shadow')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code6))

# Markdown cell 7
text7 = """
## 5. Rotating the Pie Chart
In addition to setting the start angle, you can control the rotation direction of the pie chart using the `counterclock` parameter.
"""

nb.cells.append(nbf.new_markdown_cell(text7))

# Code cell 7
code7 = """
plt.pie(sizes, labels=labels, colors=colors, startangle=90, counterclock=False)
plt.title('Pie Chart Rotated Clockwise')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code7))

# Markdown cell 8
text8 = """
In this example, setting `counterclock=False` rotates the pie chart clockwise instead of the default counterclockwise direction.

## 6. Customizing the Label Distance
The `labeldistance` parameter controls the radial distance at which the labels are drawn. You can adjust this to control how far the labels appear from the center of the pie chart.
"""

nb.cells.append(nbf.new_markdown_cell(text8))

# Code cell 8
code8 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, labeldistance=1.2)
plt.title('Pie Chart with Custom Label Distance')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code8))

# Markdown cell 9
text9 = """
In this example, the labels are drawn slightly further out from the center by setting `labeldistance=1.2`.

## 7. Customizing the Percentage Placement
The `pctdistance` parameter controls the position of the percentage labels relative to the center of the pie chart.
"""

nb.cells.append(nbf.new_markdown_cell(text9))

# Code cell 9
code9 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', pctdistance=0.85)
plt.title('Pie Chart with Custom Percentage Placement')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code9))

# Markdown cell 10
text10 = """
In this example, the percentage labels are drawn closer to the center by setting `pctdistance=0.85`.

## 8. Donut (Ring) Chart
You can create a donut chart, which is a variation of a pie chart with a hole in the center, by using the `wedgeprops` parameter to set the width of the slices.
"""

nb.cells.append(nbf.new_markdown_cell(text10))

# Code cell 10
code10 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.3})
plt.title('Donut Chart')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code10))

# Markdown cell 11
text11 = """
In this example, the `wedgeprops={'width': 0.3}` creates a ring with an inner radius of 70% of the pie's radius.

## 9. Exploding All Slices
If you want to explode all slices of the pie chart, you can specify a larger list for the `explode` parameter.
"""

nb.cells.append(nbf.new_markdown_cell(text11))

# Code cell 11
code11 = """
explode = [0.1] * len(sizes)  # Explode all slices equally

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', explode=explode)
plt.title('Pie Chart with All Slices Exploded')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code11))

# Markdown cell 12
text12 = """
## 10. Adding Legends
Sometimes, the pie chart labels can become cluttered, especially when using small slices or displaying percentages. In such cases, you can remove the labels from the chart itself and use a legend instead.
"""

nb.cells.append(nbf.new_markdown_cell(text12))

# Code cell 12
code12 = """
plt.pie(sizes, colors=colors, startangle=140)
plt.legend(labels, loc="best")
plt.title('Pie Chart with Legend')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code12))

# Markdown cell 13
text13 = """
## 11. Handling Missing or Zero Values
Pie charts can handle zero values gracefully, and such slices won't appear in the chart.
"""

nb.cells.append(nbf.new_markdown_cell(text13))

# Code cell 13
code13 = """
sizes_with_zero = [25, 0, 20, 20]  # One category with a zero value

plt.pie(sizes_with_zero, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Pie Chart with Zero Value')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code13))

# Markdown cell 14
text14 = """
In this example, the second category is given a zero value, so it will not appear in the chart.

## 12. Saving the Pie Chart
You can save the pie chart to a file using `plt.savefig()`.
"""

nb.cells.append(nbf.new_markdown_cell(text14))

# Code cell 14
code14 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Pie Chart to Save')
plt.savefig('pie_chart.png', dpi=300, bbox_inches='tight')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code14))

# Markdown cell 15
text15 = """
## 13. Pie Chart Subplots
You can create multiple pie charts in the same figure using `plt.subplot()`.
"""

nb.cells.append(nbf.new_markdown_cell(text15))

# Code cell 15
code15 = """
plt.figure(figsize=(10, 5))

# First pie chart
plt.subplot(1, 2, 1)
plt.pie(sizes, labels=labels, colors=colors, startangle=90)
plt.title('Pie Chart 1')

# Second pie chart
plt.subplot(1, 2, 2)
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Pie Chart 2')

plt.tight_layout()
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code15))

# Markdown cell 16
text16 = """
## 14. Advanced Customization with `wedgeprops` and `textprops`
The `wedgeprops` parameter allows you to customize the appearance of the pie slices, such as their edge color and width, while `textprops` allows you to customize the text properties.
"""

nb.cells.append(nbf.new_markdown_cell(text16))

# Code cell 16
code16 = """
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True,
        startangle=140, wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},
        textprops={'fontsize': 14, 'color': 'navy'})
plt.title('Pie Chart with Custom Wedge and Text Properties')
plt.show()
"""

nb.cells.append(nbf.new_code_cell(code16))

# Markdown cell 17
text17 = """
In this example:

- `wedgeprops` adds a black edge with a linewidth of 1.5 to the slices.
- `textprops` sets the font size to 14 and the text color to navy for the labels.

## Summary:
The `matplotlib.pyplot.pie` function is a powerful tool for creating pie charts in Matplotlib. It offers:

- **Basic Plotting**: Simple pie charts to visualize proportions of categorical data.
- **Customization**: Extensive control over colors, explode effects, start angles, labels, and shadows.
- **Advanced Features**: Ability to display percentages, handle missing or zero values, create donut charts, and add legends.
- **Subplots**: Create multiple pie charts in the same figure.
- **Saving Plots**: Easily save the pie charts to files for later use.

Pie charts are ideal for presenting a visual summary of data in a way that is easy to understand, especially when dealing with proportional data. Matplotlib’s `pie` function provides all the tools needed to create informative and visually appealing pie charts.
"""

nb.cells.append(nbf.new_markdown_cell(text17))

# Save the notebook
with open("Pie_chart.ipynb", "w",encoding="utf-8") as f:
    nbformat.write(nb, f)



print("Notebook 'Pie_chart.ipynb' created successfully.")
# Out:
# Notebook 'Pie_chart.ipynb' created successfully.

# %%
import nbformat as nbf

# Create a new Jupyter notebook object
nb = nbf.v4.new_notebook()

# Define the content for the notebook
content = [
    ("markdown", "# matplotlib.pyplot.boxplot\n\n"
                 "The `matplotlib.pyplot.boxplot` function is used to create box plots (also known as box-and-whisker plots) "
                 "in Matplotlib. Box plots are useful for visualizing the distribution, central tendency, and variability of a dataset. "
                 "They provide a summary of the data's minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum, "
                 "as well as any potential outliers.\n\n"
                 "### 1. Understanding Box Plot Components\n"
                 "Before diving into the details of `boxplot`, it's essential to understand the components of a box plot:\n"
                 "- **Box**: Represents the interquartile range (IQR), which is the range between the first quartile (Q1, 25th percentile) and the third quartile (Q3, 75th percentile).\n"
                 "- **Median Line**: A horizontal line inside the box representing the median (Q2, 50th percentile) of the data.\n"
                 "- **Whiskers**: Lines extending from the box to the smallest and largest values within 1.5 times the IQR from the quartiles. These represent the range of the data, excluding outliers.\n"
                 "- **Outliers**: Data points outside the whiskers are considered outliers and are typically plotted as individual points."
    ),
    ("markdown", "### 2. Basic Usage of boxplot Function\n"
                 "The simplest use of `boxplot` is to plot a single dataset. The dataset should be passed as a list or an array.\n"
                 "#### a. Creating a Simple Box Plot"
    ),
    ("code", "import matplotlib.pyplot as plt\n"
             "import numpy as np\n\n"
             "# Generate some data\n"
             "np.random.seed(10)\n"
             "data = np.random.normal(100, 20, 200)  # Mean 100, Std 20, 200 data points\n\n"
             "# Create a simple box plot\n"
             "plt.boxplot(data)\n\n"
             "# Adding labels and title\n"
             "plt.ylabel('Values')\n"
             "plt.title('Simple Box Plot')\n\n"
             "# Display the plot\n"
             "plt.show()"
    ),
    ("markdown", "### 3. Plotting Multiple Box Plots\n"
                 "You can plot multiple box plots side by side by passing a list of datasets."
    ),
    ("code", "# Generate multiple datasets\n"
             "data1 = np.random.normal(100, 20, 200)\n"
             "data2 = np.random.normal(90, 15, 200)\n"
             "data3 = np.random.normal(80, 25, 200)\n\n"
             "# Create multiple box plots\n"
             "plt.boxplot([data1, data2, data3])\n\n"
             "# Adding labels and title\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.ylabel('Values')\n"
             "plt.title('Multiple Box Plots')\n\n"
             "# Display the plot\n"
             "plt.show()"
    ),
    ("markdown", "### 4. Customizing Box Plots\n"
                 "Matplotlib allows you to customize various aspects of box plots, including colors, orientations, outlier markers, and more.\n"
                 "#### a. Changing Box Colors"
    ),
    ("code", "plt.boxplot([data1, data2, data3], \n"
             "            boxprops=dict(color='blue'),\n"
             "            whiskerprops=dict(color='red'),\n"
             "            flierprops=dict(marker='o', color='green', markersize=5))\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Box Plot with Custom Colors')\n"
             "plt.show()"
    ),
    ("markdown", "#### b. Horizontal Box Plots\n"
                 "By default, box plots are vertical, but you can create horizontal box plots by setting the `vert` parameter to `False`."
    ),
    ("code", "plt.boxplot([data1, data2, data3], vert=False)\n\n"
             "plt.yticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.xlabel('Values')\n"
             "plt.title('Horizontal Box Plot')\n"
             "plt.show()"
    ),
    ("markdown", "#### c. Customizing Outliers\n"
                 "You can change the appearance of the outliers using the `flierprops` parameter."
    ),
    ("code", "plt.boxplot([data1, data2, data3], \n"
             "            flierprops=dict(marker='x', color='red', markersize=8))\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Box Plot with Custom Outliers')\n"
             "plt.show()"
    ),
    ("markdown", "### 5. Advanced Box Plot Customizations\n"
                 "#### a. Adding Notches\n"
                 "Notched box plots show confidence intervals around the median. The notch represents the uncertainty about the true median."
    ),
    ("code", "plt.boxplot([data1, data2, data3], notch=True)\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Notched Box Plot')\n"
             "plt.show()"
    ),
    ("markdown", "#### b. Changing Whisker Length\n"
                 "The length of the whiskers can be controlled using the `whis` parameter. The default is 1.5 times the IQR."
    ),
    ("code", "plt.boxplot([data1, data2, data3], whis=2.0)\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Box Plot with Custom Whisker Length')\n"
             "plt.show()"
    ),
    ("markdown", "#### c. Displaying Means\n"
                 "You can display the mean of the data in the box plot using the `showmeans` parameter."
    ),
    ("code", "plt.boxplot([data1, data2, data3], showmeans=True)\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Box Plot with Means')\n"
             "plt.show()"
    ),
    ("markdown", "### 6. Grouped Box Plots\n"
                 "Grouped box plots are useful for comparing multiple groups within different categories."
    ),
    ("code", "# Generate more datasets for grouping\n"
             "data4 = np.random.normal(70, 30, 200)\n"
             "data5 = np.random.normal(60, 20, 200)\n"
             "data6 = np.random.normal(50, 25, 200)\n\n"
             "# Grouped box plots\n"
             "data = [data1, data2, data3, data4, data5, data6]\n"
             "plt.boxplot(data, \n"
             "            patch_artist=True,  # Fill with color\n"
             "            medianprops=dict(color='yellow'),\n"
             "            boxprops=dict(facecolor='lightblue'))\n\n"
             "# Customizing x-ticks for grouped data\n"
             "plt.xticks([1, 2, 3, 4, 5, 6], ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', 'Group 6'])\n"
             "plt.title('Grouped Box Plots')\n"
             "plt.show()"
    ),
    ("markdown", "### 7. Violin Plots vs. Box Plots\n"
                 "Sometimes, it’s helpful to use violin plots instead of box plots to visualize the distribution of data. Violin plots are similar to box plots but also show the probability density of the data at different values."
    ),
    ("code", "plt.violinplot([data1, data2, data3])\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Violin Plot')\n"
             "plt.show()"
    ),
    ("markdown", "### 8. Customizing Whiskers and Caps\n"
                 "You can further customize the appearance of whiskers and caps using the `whiskerprops` and `capprops` parameters."
    ),
    ("code", "plt.boxplot([data1, data2, data3],\n"
             "            whiskerprops=dict(color='black', linewidth=2),\n"
             "            capprops=dict(color='red', linewidth=2))\n\n"
             "plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])\n"
             "plt.title('Box Plot with Custom Whiskers and Caps')\n"
             "plt.show()"
    ),
      ("markdown", "### 9. Logarithmic Scale\n"
                 "You can use a `logarithmic scale` for the y-axis to better visualize data with a wide range."
    ),
    ("code", "plt.boxplot([data1, data2, data3],\n"
             "plt.yscale('log')\n"
             "plt.title('Box Plot with logarithmic scale')\n"
             "plt.show()"
    ),
     ("markdown", "### 10. Saving the Box Plot\n"
                 "You can save the box plot to a file using `plt.savefig()`."
    ),
    ("code", 
             """
            plt.boxplot([data1, data2, data3], showmeans=True)
            plt.title('Box Plot to Save')
            plt.savefig('box_plot.png', dpi=300, bbox_inches='tight')
            plt.show()
            """
    ),
    ("markdown", "### 11. Box Plot Subplots\n"
                 "You can create multiple box plots in the same figure using `plt.subplot()`."
    ),
    ("code", 
             """
                plt.figure(figsize=(10, 5))
                
                # First box plot
                plt.subplot(1, 2, 1)
                plt.boxplot(data1)
                plt.title('Box Plot 1')
                
                # Second box plot
                plt.subplot(1, 2, 2)
                plt.boxplot(data2)
                plt.title('Box Plot 2')
                
                plt.tight_layout()
                plt.show()

            """
    ),
        ("markdown", 
         
         "### Sumary:\n"
         """
        The `matplotlib.pyplot.boxplot` function is a versatile and powerful tool for visualizing the distribution and variability of data. It offers:
           
            - **Basic Plotting**: Simple box plots to summarize datasets.
            - **Customization**: Extensive control over colors, whiskers, outliers, notches, and orientation.
            - **Advanced Features**: Ability to show means, control whisker length, and group box plots.
            - **Comparison with Violin Plots**: Visualize full distributions using violin plots as an alternative to box plots.
            - **Subplots and Saving**: Create multiple box plots in a single figure and save them for later use.
        
        Box plots are essential for statistical data analysis, providing a clear summary of the data’s spread, central tendency, and potential outliers. Matplotlib’s `boxplot` function enables the creation of informative and visually appealing box plots with ease.

         """
    )

]


# Add cells to the notebook
for cell_type, content in content:
    if cell_type == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(content))
    elif cell_type == "code":
        nb.cells.append(nbf.v4.new_code_cell(content))

# Write the notebook to a file
with open("Boxplot.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook 'Boxplot.ipynb' created successfully.")
# Out:
# Notebook 'Boxplot.ipynb' created successfully.

# %% [markdown]
# # The below code is for the creation of boxplot_keyterms
# import nbformat as nbf
#
# # Create a new notebook
# nb = nbf.v4.new_notebook()
#
# # Define the cells with the provided text
# cells = [
#     nbf.v4.new_markdown_cell("""
# # Key terms associated with Boxplots
# Boxplots are a powerful tool for summarizing and visualizing the distribution of a dataset. To fully understand a boxplot, it's important to grasp the key terms associated with it. Below, I’ll explain these terms and illustrate them with examples using Python's Matplotlib.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 1. Minimum
# - The smallest data point, excluding any outliers.
# - Example: Consider the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`. The minimum value here is 1.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 2. Maximum
# - The largest data point, excluding any outliers.
# - Example: In the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the maximum value is 8, as 100 might be considered an outlier.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 3. Median (Q2)
# - The middle value of the dataset when arranged in ascending order. It divides the data into two equal halves.
# - Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the median is 5.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 4. First Quartile (Q1)
# - The median of the lower half of the dataset (excluding the median if the number of observations is odd). It marks the 25th percentile.
# - Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the first quartile is 3.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 5. Third Quartile (Q3)
# - The median of the upper half of the dataset (excluding the median if the number of observations is odd). It marks the 75th percentile.
# - Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the third quartile is 7.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 6. Interquartile Range (IQR)
# - The difference between the third quartile and the first quartile. It measures the spread of the middle 50% of the data.
# - Formula: `IQR = Q3 - Q1`
# - Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the IQR is `7 - 3 = 4`.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 7. Whiskers
# - Lines that extend from the quartiles to the minimum and maximum values within 1.5 times the IQR from the lower and upper quartiles, respectively. Whiskers indicate the range of the data.
# - Example: In the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the lower whisker might extend to 1, and the upper whisker might extend to 8.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 8. Outliers
# - Data points that fall outside the range defined by 1.5 times the IQR from Q1 and Q3. Outliers are shown as individual points beyond the whiskers.
# - Example: In the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, 100 is an outlier because it is significantly higher than the rest of the data.
# """),
#     nbf.v4.new_markdown_cell("""
# ## 9. Notch
# - A notch around the median line indicates a confidence interval around the median. If the notches of two boxplots do not overlap, it suggests a statistically significant difference between the medians.
# - Example: In a boxplot of two datasets, if the notch around the median of one dataset does not overlap with the notch of the other, it suggests that their medians are significantly different.
# """),
#     nbf.v4.new_markdown_cell("""
# ## Example in Matplotlib
# Let’s create a boxplot with a dataset that illustrates these terms:
# """),
#     nbf.v4.new_code_cell("""
# import matplotlib.pyplot as plt
#
# # Example datasets
# data = [1, 2, 3, 4, 5, 6, 7, 8, 100]
#
# # Creating the boxplot
# plt.boxplot(data, notch=True, patch_artist=True,
#             boxprops=dict(facecolor='lightblue', color='blue'),
#             medianprops=dict(color='darkblue', linewidth=2),
#             whiskerprops=dict(color='blue', linewidth=2),
#             capprops=dict(color='blue', linewidth=2),
#             flierprops=dict(marker='o', color='red', alpha=0.5))
#
# # Adding titles and labels
# plt.title('Boxplot Example')
# plt.xticks([1], ['Dataset'])
# plt.ylabel('Value')
# plt.show()
# """),
#     nbf.v4.new_markdown_cell("""
# ## Interpretation of the Example Boxplot
# - **Minimum and Maximum**: The whiskers extend to the smallest value (1) and largest value within the acceptable range (8).
# - **Median (Q2)**: The dark blue line inside the box at 5 represents the median.
# - **First Quartile (Q1)**: The lower edge of the box at 3 represents the first quartile.
# - **Third Quartile (Q3)**: The upper edge of the box at 7 represents the third quartile.
# - **Interquartile Range (IQR)**: The box’s height represents the IQR, which is 4 in this case.
# - **Outliers**: The point 100 is plotted outside the whiskers and is marked as a red dot, indicating it's an outlier.
# - **Notch**: The indentation around the median indicates a confidence interval around the median, helping in comparison with other boxplots.
# """),
#     nbf.v4.new_markdown_cell("""
# ## Conclusion
# Understanding these terms helps you accurately interpret and analyze boxplots. By recognizing the minimum, maximum, quartiles, IQR, whiskers, and outliers, you can gain valuable insights into the distribution and variability of your data.
# """)
# ]
#
# # Add cells to the notebook
# nb['cells'].extend(cells)
#
# # Write the notebook to a file
# with open('boxplot_key_terms.ipynb', 'w', encoding="utf-8") as f:
#     nbf.write(nb, f)
#
# print("Notebook 'boxplot_key_terms.ipynb' created successfully.")

# %% [markdown]
# # Note
# In below code , we use the append method for updating the existing file `Boxplot.ipynb`

# %%
import nbformat as nbf

# Create a new notebook
# nb = nbf.v4.new_notebook()

# Read the existing notebook
with open("Boxplot.ipynb", "r", encoding="utf-8") as f:
    nb = nbf.read(f, as_version=4)

# Add new content to the notebook (example: adding a new markdown cell)
cells = [
    nbf.v4.new_markdown_cell("""
# Key terms associated with Boxplots
Boxplots are a powerful tool for summarizing and visualizing the distribution of a dataset. To fully understand a boxplot, it's important to grasp the key terms associated with it. Below, I’ll explain these terms and illustrate them with examples using Python's Matplotlib.
"""),
    nbf.v4.new_markdown_cell("""
## 1. Minimum
- The smallest data point, excluding any outliers.
- Example: Consider the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`. The minimum value here is 1.
"""),
    nbf.v4.new_markdown_cell("""
## 2. Maximum
- The largest data point, excluding any outliers.
- Example: In the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the maximum value is 8, as 100 might be considered an outlier.
"""),
    nbf.v4.new_markdown_cell("""
## 3. Median (Q2)
- The middle value of the dataset when arranged in ascending order. It divides the data into two equal halves.
- Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the median is 5.
"""),
    nbf.v4.new_markdown_cell("""
## 4. First Quartile (Q1)
- The median of the lower half of the dataset (excluding the median if the number of observations is odd). It marks the 25th percentile.
- Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the first quartile is 3.
"""),
    nbf.v4.new_markdown_cell("""
## 5. Third Quartile (Q3)
- The median of the upper half of the dataset (excluding the median if the number of observations is odd). It marks the 75th percentile.
- Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the third quartile is 7.
"""),
    nbf.v4.new_markdown_cell("""
## 6. Interquartile Range (IQR)
- The difference between the third quartile and the first quartile. It measures the spread of the middle 50% of the data.
- Formula: `IQR = Q3 - Q1`
- Example: For the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the IQR is `7 - 3 = 4`.
"""),
    nbf.v4.new_markdown_cell("""
## 7. Whiskers
- Lines that extend from the quartiles to the minimum and maximum values within 1.5 times the IQR from the lower and upper quartiles, respectively. Whiskers indicate the range of the data.
- Example: In the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, the lower whisker might extend to 1, and the upper whisker might extend to 8.
"""),
    nbf.v4.new_markdown_cell("""
## 8. Outliers
- Data points that fall outside the range defined by 1.5 times the IQR from Q1 and Q3. Outliers are shown as individual points beyond the whiskers.
- Example: In the dataset `[1, 2, 3, 4, 5, 6, 7, 8, 100]`, 100 is an outlier because it is significantly higher than the rest of the data.
"""),
    nbf.v4.new_markdown_cell("""
## 9. Notch
- A notch around the median line indicates a confidence interval around the median. If the notches of two boxplots do not overlap, it suggests a statistically significant difference between the medians.
- Example: In a boxplot of two datasets, if the notch around the median of one dataset does not overlap with the notch of the other, it suggests that their medians are significantly different.
"""),
    nbf.v4.new_markdown_cell("""
## Example in Matplotlib
Let’s create a boxplot with a dataset that illustrates these terms:
"""),
    nbf.v4.new_code_cell("""
import matplotlib.pyplot as plt

# Example datasets
data = [1, 2, 3, 4, 5, 6, 7, 8, 100]

# Creating the boxplot
plt.boxplot(data, notch=True, patch_artist=True,
            boxprops=dict(facecolor='lightblue', color='blue'),
            medianprops=dict(color='darkblue', linewidth=2),
            whiskerprops=dict(color='blue', linewidth=2),
            capprops=dict(color='blue', linewidth=2),
            flierprops=dict(marker='o', color='red', alpha=0.5))

# Adding titles and labels
plt.title('Boxplot Example')
plt.xticks([1], ['Dataset'])
plt.ylabel('Value')
plt.show()
"""),
    nbf.v4.new_markdown_cell("""
## Interpretation of the Example Boxplot
- **Minimum and Maximum**: The whiskers extend to the smallest value (1) and largest value within the acceptable range (8).
- **Median (Q2)**: The dark blue line inside the box at 5 represents the median.
- **First Quartile (Q1)**: The lower edge of the box at 3 represents the first quartile.
- **Third Quartile (Q3)**: The upper edge of the box at 7 represents the third quartile.
- **Interquartile Range (IQR)**: The box’s height represents the IQR, which is 4 in this case.
- **Outliers**: The point 100 is plotted outside the whiskers and is marked as a red dot, indicating it's an outlier.
- **Notch**: The indentation around the median indicates a confidence interval around the median, helping in comparison with other boxplots.
"""),
    nbf.v4.new_markdown_cell("""
## Conclusion
Understanding these terms helps you accurately interpret and analyze boxplots. By recognizing the minimum, maximum, quartiles, IQR, whiskers, and outliers, you can gain valuable insights into the distribution and variability of your data.
""")
]

# Add cells to the notebook
nb['cells'].extend(cells)

# Write the updated notebook back to the file
with open("Boxplot.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("Boxplot.ipynb Updated")
# Out:
# Boxplot.ipynb Updated

# %%
import nbformat as nbf

# Create a new notebook
nb = nbf.v4.new_notebook()

# Define the cells
cells = [
    nbf.v4.new_markdown_cell("""
# Understanding Histograms in Matplotlib

The `matplotlib.pyplot.hist` function is used to create histograms in Matplotlib. A histogram is a graphical representation that organizes a group of data points into user-specified ranges, showing the frequency distribution of the data. It is particularly useful for understanding the distribution, spread, and shape of continuous data.
    """),
    nbf.v4.new_markdown_cell("""
## 1. Understanding Histograms

A histogram displays data by grouping it into bins or intervals. Each bin has a bar, and the height of the bar represents the frequency (or count) of data points in that bin. Histograms are useful for visualizing the underlying distribution of data, such as whether it is skewed, bimodal, or has outliers.
    """),
    nbf.v4.new_markdown_cell("""
## 2. Basic Usage of `hist` Function

The `hist` function requires at least one input: the data to be plotted. By default, the function divides the data into 10 bins.
    """),
    nbf.v4.new_code_cell("""
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
np.random.seed(42)
data = np.random.randn(1000)  # 1000 data points from a standard normal distribution

# Create a simple histogram
plt.hist(data)

# Adding labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Simple Histogram')

# Display the plot
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
In this example:
- `data` is a list or array of numerical values to be visualized.
- `hist` creates the histogram, dividing the data into bins and plotting the frequency of data points in each bin.
    """),
    nbf.v4.new_markdown_cell("""
## 3. Customizing the Number of Bins

You can control the number of bins by specifying the `bins` parameter. The choice of the number of bins can significantly affect the appearance and interpretability of the histogram.
    """),
    nbf.v4.new_code_cell("""
# Histogram with a different number of bins
plt.hist(data, bins=30)  # 30 bins

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with 30 Bins')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
In this example:
- `bins=30` specifies that the data should be divided into 30 bins.
    """),
    nbf.v4.new_markdown_cell("""
## 4. Customizing Colors and Transparency

You can customize the appearance of the histogram by changing the color of the bars and adjusting the transparency.
    """),
    nbf.v4.new_markdown_cell("""
### a. Changing the Bar Color

The `color` parameter allows you to set the color of the bars.
    """),
    nbf.v4.new_code_cell("""
plt.hist(data, bins=30, color='skyblue')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Custom Bar Color')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
### b. Adjusting the Transparency

The `alpha` parameter controls the transparency of the bars. A value of 1 is fully opaque, and 0 is fully transparent.
    """),
    nbf.v4.new_code_cell("""
plt.hist(data, bins=30, color='skyblue', alpha=0.7)

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Transparency')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 5. Plotting Multiple Histograms

You can plot multiple histograms on the same plot, either overlapping or side-by-side.
    """),
    nbf.v4.new_markdown_cell("""
### a. Overlapping Histograms
    """),
    nbf.v4.new_code_cell("""
# Generate another dataset
data2 = np.random.randn(1000) + 2  # Shifted by +2

plt.hist(data, bins=30, color='blue', alpha=0.5, label='Data 1')
plt.hist(data2, bins=30, color='orange', alpha=0.5, label='Data 2')

# Adding labels, title, and legend
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Overlapping Histograms')
plt.legend()

plt.show()
    """),
    nbf.v4.new_markdown_cell("""
### b. Side-by-Side Histograms

To create side-by-side histograms, use the `plt.hist()` function with the `density` parameter set to `True` and adjust the width of the bins.
    """),
    nbf.v4.new_code_cell("""
plt.hist(data, bins=15, color='blue', alpha=0.7, label='Data 1', density=True, edgecolor='black')
plt.hist(data2, bins=15, color='orange', alpha=0.7, label='Data 2', density=True, edgecolor='black')

# Adding labels, title, and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Side-by-Side Histograms')
plt.legend()

plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 6. Cumulative Histograms

You can create cumulative histograms by setting the `cumulative` parameter to `True`. This shows the cumulative sum of the data, useful for understanding the proportion of data below a certain threshold.
    """),
    nbf.v4.new_code_cell("""
plt.hist(data, bins=30, cumulative=True, color='green', alpha=0.7)

plt.xlabel('Value')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Histogram')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 7. Normalizing Histograms

By setting the `density` parameter to `True`, you can normalize the histogram so that the area under the histogram is equal to 1. This is useful when comparing histograms with different sample sizes.
    """),
    nbf.v4.new_code_cell("""
plt.hist(data, bins=30, color='purple', density=True)

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Normalized Histogram')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 8. Customizing the Binning

You can define custom bin edges by passing a list or array to the `bins` parameter.
    """),
    nbf.v4.new_code_cell("""
custom_bins = [-3, -2, -1, 0, 1, 2, 3]

plt.hist(data, bins=custom_bins, color='red', alpha=0.7, edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Custom Bins')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 9. Histogram with Logarithmic Scale

For data that spans several orders of magnitude, you can use a logarithmic scale for the y-axis.
    """),
    nbf.v4.new_code_cell("""
data3 = np.random.exponential(scale=1.0, size=1000)

plt.hist(data3, bins=30, color='teal', log=True)

plt.xlabel('Value')
plt.ylabel('Frequency (log scale)')
plt.title('Histogram with Logarithmic Scale')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 10. 2D Histograms

Matplotlib also allows for the creation of 2D histograms, which show the joint distribution of two variables.
    """),
    nbf.v4.new_code_cell("""
x = np.random.randn(1000)
y = np.random.randn(1000)

plt.hist2d(x, y, bins=30, cmap='Blues')
plt.colorbar()  # Add color bar to show scale

plt.xlabel('X Value')
plt.ylabel('Y Value')
plt.title('2D Histogram')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 11. Adding Fit Lines

You can add a line representing a fitted distribution (like a normal distribution) to the histogram.
    """),
    nbf.v4.new_code_cell("""
from scipy.stats import norm

# Fit a normal distribution to the data
mu, std = norm.fit(data)

# Plot the histogram
plt.hist(data, bins=30, density=True, color='lightgreen', alpha=0.7, edgecolor='black')

# Plot the fitted normal distribution
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram with Normal Distribution Fit')
plt.show()
    """),
    nbf.v4.new_markdown_cell("""
## 12. Histogram Subplots

You can create multiple histograms in the same figure using `plt.subplot()`.
    """),
    nbf.v4.new_code_cell("""
plt.figure(figsize=(10, 5))

# First subplot
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='blue', alpha=0.7)
plt.title('Histogram 1')

# Second subplot
plt.subplot(1, 2, 2)
plt.hist(data2, bins=30, color='orange', alpha=0.7)
plt.title('Histogram 2')

plt.tight_layout()
plt.show()
    """),

     nbf.v4.new_markdown_cell("""
## 13. Saving the Histogram
You can save the histogram to a file using `plt.savefig()`.
    """),
    nbf.v4.new_code_cell("""
plt.hist(data, bins=30, color='purple', alpha=0.7)
plt.title('Histogram to Save')
plt.savefig('histogram.png', dpi=300, bbox_inches='tight')
plt.show()
    """),
         nbf.v4.new_markdown_cell("""
## 14. Overlaying a KDE (Kernel Density Estimate)
Sometimes it’s helpful to overlay a KDE plot on the histogram to visualize the smoothed distribution.
    """),
    nbf.v4.new_code_cell("""
import seaborn as sns

plt.hist(data, bins=30, density=True, color='lightblue', alpha=0.6)
sns.kdeplot(data, color='blue', linewidth=2)

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram with KDE')
plt.show()

    """),
             nbf.v4.new_markdown_cell("""
In this example, Seaborn’s `kdeplot` function is used to overlay a kernel density estimate (KDE) on top of the histogram.    
"""),
        nbf.v4.new_markdown_cell("""
## Summary:
The `matplotlib.pyplot.hist` function is a versatile tool for creating histograms in Matplotlib. It offers:
- **Basic Plotting**: Simple histograms to visualize the frequency distribution of data.
- **Customization**: Control over the number of bins, colors, transparency, and more.
- **Advanced Features**: Ability to create cumulative histograms, normalized histograms, 2D histograms, and apply logarithmic scales.
- **Overlaying Fits**: Add distribution fit lines or KDE plots to visualize underlying distributions.
- **Subplots and Saving**: Create multiple histograms in one figure and save them for later use.

Histograms are essential for data analysis, providing a clear and concise view of the distribution and spread of the data. Matplotlib’s `hist` function enables the creation of informative and visually appealing histograms, making it a powerful tool in any data scientist’s toolkit.
""")
    
]

# Add all cells to the notebook
nb['cells'] = cells

# Write the notebook to a file
with open('Histograms.ipynb', 'w', encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook Histograms.ipynb created.")
# Out:
# Notebook Histograms.ipynb created.

# %%
import nbformat as nbf

# Create a new Jupyter notebook
nb = nbf.v4.new_notebook()

# Text for the notebook
text = [
    ("markdown", "# `matplotlib.pyplot.violinplot`\n"
                 "The `matplotlib.pyplot.violinplot` function is used to create violin plots in Matplotlib. "
                 "A violin plot is a method of plotting numeric data and can be understood as a combination "
                 "of a box plot and a kernel density plot. It provides a richer description of the distribution "
                 "of data, showing both the density and summary statistics like the median, quartiles, and outliers."),

    ("markdown", "## 1. Understanding Violin Plots\n"
                 "A violin plot displays the distribution of data across different categories:\n"
                 "- **Density**: The width of the violin at any given point indicates the density of the data, "
                 "similar to a kernel density estimate (KDE).\n"
                 "- **Box Plot Features**: Inside the violin, there can be a marker for the median and a box for the "
                 "interquartile range (IQR), similar to a traditional box plot.\n"
                 "- **Multiple Distributions**: Violin plots are particularly useful for comparing multiple distributions side by side."),

    ("markdown", "## 2. Basic Usage of `violinplot` Function\n"
                 "The `violinplot` function requires at least one input: the data to be plotted. The data should be passed as a list or array, "
                 "where each sub-array represents a different distribution."),

    ("markdown", "### a. Creating a Simple Violin Plot"),
    ("code", "import matplotlib.pyplot as plt\n"
             "import numpy as np\n\n"
             "# Generate some random data\n"
             "np.random.seed(42)\n"
             "data = [np.random.normal(0, std, 100) for std in range(1, 4)]\n\n"
             "# Create a simple violin plot\n"
             "plt.violinplot(data)\n\n"
             "# Adding labels and title\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Simple Violin Plot')\n\n"
             "# Display the plot\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `data` is a list of numerical arrays representing different distributions.\n"
                 "- `violinplot` generates the violin plot for each dataset."),

    ("markdown", "## 3. Customizing Violin Plots\n"
                 "Matplotlib allows you to customize various aspects of violin plots, including the appearance of the violins, the orientation, "
                 "and the inclusion of box plot features."),

    ("markdown", "### a. Changing Violin Colors"),
    ("code", "plt.violinplot(data, showmeans=False, showmedians=True, showextrema=True)\n\n"
             "# Customize the violin plot's appearance\n"
             "for pc in plt.violinplot(data, showmeans=False, showmedians=True, showextrema=True)['bodies']:\n"
             "    pc.set_facecolor('lightblue')\n"
             "    pc.set_edgecolor('blue')\n"
             "    pc.set_alpha(0.7)\n\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Violin Plot with Custom Colors')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `set_facecolor` changes the interior color of the violin.\n"
                 "- `set_edgecolor` changes the color of the violin's edges.\n"
                 "- `set_alpha` adjusts the transparency of the violin."),

    ("markdown", "### b. Horizontal Violin Plots"),
    ("code", "plt.violinplot(data, vert=False)\n\n"
             "plt.ylabel('Category')\n"
             "plt.xlabel('Value')\n"
             "plt.title('Horizontal Violin Plot')\n"
             "plt.show()"),

    ("markdown", "### c. Displaying Means and Medians"),
    ("code", "plt.violinplot(data, showmeans=True, showmedians=True, showextrema=True)\n\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Violin Plot with Means and Medians')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `showmeans=True` adds a marker for the mean.\n"
                 "- `showmedians=True` adds a marker for the median.\n"
                 "- `showextrema=True` displays the range of the data."),

    ("markdown", "## 4. Customizing the Kernel Density Estimation\n"
                 "The kernel density estimation (KDE) used in the violin plot can be customized using the `bw_method` (bandwidth) "
                 "and `kde` (kernel) parameters. This allows you to control the smoothness of the distribution."),

    ("markdown", "### a. Adjusting Bandwidth"),
    ("code", "plt.violinplot(data, bw_method=0.2)  # Smaller bandwidth\n\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Violin Plot with Adjusted Bandwidth')\n"
             "plt.show()"),

    ("markdown", "### b. Specifying the Number of Points"),
    ("code", "plt.violinplot(data, points=200)  # More points for smoother plot\n\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Violin Plot with More Points')\n"
             "plt.show()"),

    ("markdown", "## 5. Split Violin Plots\n"
                 "Split violin plots are useful when comparing two distributions side by side within the same category. "
                 "This is particularly useful for showing the difference between two related groups."),

    ("code", "data1 = np.random.normal(0, 1, 100)\n"
             "data2 = np.random.normal(1, 1.5, 100)\n\n"
             "# Combine data into one list\n"
             "data_combined = [data1, data2]\n\n"
             "plt.violinplot(data_combined, showmeans=False, showmedians=True, showextrema=False)\n\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Split Violin Plot')\n"
             "plt.show()"),

    ("markdown", "In this example, `split=True` would have been used to create a split violin plot if the data were structured to support it. "
                 "However, `matplotlib.pyplot.violinplot` does not natively support split violins directly, so you would typically use libraries like "
                 "Seaborn for that purpose. In pure Matplotlib, this effect would require manual customization."),

    ("markdown", "## 6. Comparing Multiple Categories\n"
                 "You can plot multiple violin plots side by side to compare the distributions across different categories."),

    ("code", "data3 = np.random.normal(2, 0.5, 100)\n"
             "data4 = np.random.normal(-1, 2, 100)\n\n"
             "data_combined = [data1, data2, data3, data4]\n\n"
             "plt.violinplot(data_combined, showmeans=False, showmedians=True, showextrema=True)\n\n"
             "# Customize x-ticks for each category\n"
             "plt.xticks([1, 2, 3, 4], ['Category 1', 'Category 2', 'Category 3', 'Category 4'])\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Violin Plot for Multiple Categories')\n"
             "plt.show()"),

    ("markdown", "## 7. Overlaying Violin Plots with Other Plots\n"
                 "You can overlay violin plots with other plots, such as scatter plots, box plots, or strip plots, to provide additional context."),

    ("code", "plt.violinplot(data_combined, showmeans=False, showmedians=True, showextrema=True)\n\n"
             "# Overlay with a scatter plot\n"
             "for i, d in enumerate(data_combined):\n"
             "    plt.scatter([i + 1] * len(d), d, alpha=0.3)\n\n"
             "plt.xticks([1, 2, 3, 4], ['Category 1', 'Category 2', 'Category 3', 'Category 4'])\n"
             "plt.xlabel('Category')\n"
             "plt.ylabel('Value')\n"
             "plt.title('Violin Plot with Overlayed Scatter Plot')\n"
             "plt.show()"),

    ("markdown", "## 8. Customizing the Violin Plot Components\n"
                 "You can customize specific components of the violin plot, such as the box inside the violin or the whiskers."),
    ("code", 
     """
     parts = plt.violinplot(data_combined, showmeans=False, showmedians=True, showextrema=True)

    # Customizing the median line
    for partname in ('cbars', 'cmins', 'cmaxes'):
        vp = parts[partname]
        vp.set_edgecolor('black')
        vp.set_linewidth(1)
    
    plt.xticks([1, 2, 3, 4], ['Category 1', 'Category 2', 'Category 3', 'Category 4'])
    plt.xlabel('Category')
    plt.ylabel('Value')
    plt.title('Customized Violin Plot')
    plt.show()

     """
    ),

    
    ("markdown", "In this example:\n"
                 "- `cbars`, `cmins`, `cmaxes` refer to the components of the violin plot (center bars, min lines, max lines).\n"
                 "- You can use `set_edgecolor` and `set_linewidth` to customize their appearance."),

    ("markdown", "## 9. Histogram or KDE Overlay\n"
                 "If you want to overlay a histogram or a KDE plot on top of a violin plot, you can manually draw it using `plt.hist()` or Seaborn’s `kdeplot()`."),

        ("code", 
     """
    import seaborn as sns
    
    sns.violinplot(data=data_combined, inner=None)  # Disable internal box plot
    
    # Overlay KDE plot
    for d in data_combined:
        sns.kdeplot(d, bw_adjust=0.5)
    
    plt.xticks([0, 1, 2, 3], ['Category 1', 'Category 2', 'Category 3', 'Category 4'])
    plt.xlabel('Category')
    plt.ylabel('Density')
    plt.title('Violin Plot with KDE Overlay')
    plt.show()

     """
    ),
    ("markdown", "## 10. Saving the Violin Plot\n"
                 "You can save the violin plot to a file using `plt.savefig()`."),
    ("code", 
     """
    plt.violinplot(data_combined, showmeans=True, showmedians=True, showextrema=True)
    plt.title('Violin Plot to Save')
    plt.savefig('violin_plot.png', dpi=300, bbox_inches='tight')
    plt.show()
     """
    ),
    
    ("markdown", "## 11. Violin Plot Subplots\n"
                 "You can create multiple violin plots in the same figure using `plt.subplot()`."),

        ("code", 
     """
    plt.figure(figsize=(10, 5))
    
    # First subplot
    plt.subplot(1, 2, 1)
    plt.violinplot(data1, showmeans=True, showmedians=True)
    plt.title('Violin Plot 1')
    
    # Second subplot
    plt.subplot(1, 2, 2)
    plt.violinplot(data2, showmeans=True, showmedians=True)
    plt.title('Violin Plot 2')
    
    plt.tight_layout()
    plt.show()

     """
    ),
    ("markdown", "## Summary\n"
                 "The `matplotlib.pyplot.violinplot` function is a versatile tool for creating violin plots in Matplotlib. It offers:\n"
                 "- **Basic Plotting**: Simple violin plots to visualize the distribution of data across different categories.\n"
                 "- **Customization**: Extensive control over colors, orientation, display of means, medians, and extrema, and KDE smoothness.\n"
                 "- **Advanced Features**: Ability to create split violin plots, compare multiple distributions, and overlay other plot types.\n"
                 "- **Subplots and Saving**: Create multiple violin plots in one figure and save them for later use.\n"
                 "Violin plots are particularly useful when you want to understand the distribution of data beyond what a box plot can provide, especially "
                 "for comparing multiple distributions side by side. Matplotlib’s `violinplot` function enables the creation of informative and visually appealing "
                 "violin plots with ease.")
]

# Add each cell to the notebook
for cell_type, cell_content in text:
    if cell_type == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(cell_content))
    elif cell_type == "code":
        nb.cells.append(nbf.v4.new_code_cell(cell_content))

# Save the notebook to a file
with open("Violinplot.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)
print("Notebook Violinplot.ipynb created.")
# Out:
# Notebook Violinplot.ipynb created.

# %%
import nbformat as nbf

# Create a new notebook
nb = nbf.v4.new_notebook()

# Content to be added to the notebook
text = [
    ("markdown", "# matplotlib.pyplot.stem\n"
                 "The `matplotlib.pyplot.stem` function is used to create stem plots in Matplotlib. A stem plot is a type of discrete plot that displays data as vertical lines (stems) extending from a baseline along the x-axis to a series of markers (usually circles) at the data points. Stem plots are particularly useful for visualizing discrete data points and are often used in signal processing and other areas where data is sampled at regular intervals."),

    ("markdown", "## 1. Understanding Stem Plots\n"
                 "A stem plot consists of the following components:\n"
                 "- **Stems**: Vertical lines extending from the baseline (usually the x-axis) to the data points.\n"
                 "- **Markers**: Symbols (often circles) that are placed at the end of each stem to represent the data points.\n"
                 "- **Baseline**: A horizontal line (usually along the x-axis) from which the stems originate.\n"
                 "Stem plots are useful when you want to emphasize the individual data points rather than the connections between them, as in a line plot."),

    ("markdown", "## 2. Basic Usage of `stem` Function\n"
                 "The `stem` function requires at least two inputs: the x-values and the y-values. The x-values represent the positions of the stems along the x-axis, while the y-values represent the heights of the stems."),

    ("markdown", "### a. Creating a Simple Stem Plot"),
    ("code", "import matplotlib.pyplot as plt\n"
             "import numpy as np\n\n"
             "# Generate some data\n"
             "x = np.linspace(0, 2 * np.pi, 10)\n"
             "y = np.sin(x)\n\n"
             "# Create a simple stem plot\n"
             "plt.stem(x, y)\n\n"
             "# Adding labels and title\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Simple Stem Plot')\n\n"
             "# Display the plot\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `x` represents the positions of the data points along the x-axis.\n"
                 "- `y` represents the values at each position, corresponding to the height of the stems.\n"
                 "- `stem` creates the stem plot, with vertical lines extending from the x-axis to the data points."),

    ("markdown", "## 3. Customizing Stem Plots\n"
                 "Matplotlib allows you to customize various aspects of stem plots, including the appearance of the stems, markers, and baseline."),

    ("markdown", "### a. Changing Marker Style and Color"),
    ("code", "plt.stem(x, y, markerfmt='ro')  # Red circle markers\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stem Plot with Custom Markers')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `markerfmt='ro'` sets the markers to red circles ('r' for red, 'o' for circles).\n"
                 "You can use other marker styles (e.g., 's' for squares, '^' for triangles) and colors (e.g., 'g' for green, 'b' for blue)."),

    ("markdown", "### b. Changing Stem Line Style and Color"),
    ("code", "plt.stem(x, y, linefmt='g--')  # Green dashed stems\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stem Plot with Custom Stem Lines')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `linefmt='g--'` sets the stems to green dashed lines ('g' for green, '--' for dashed lines)."),

    ("markdown", "### c. Changing the Baseline"),
    ("code", "plt.stem(x, y, basefmt='r-')  # Red solid baseline\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stem Plot with Custom Baseline')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `basefmt='r-'` sets the baseline to a red solid line ('r' for red, '-' for solid lines)."),

    ("markdown", "## 4. Horizontal Stem Plots\n"
                 "While stem plots are typically vertical, you can create horizontal stem plots by swapping the x and y data."),
    ("code", "plt.stem(y, x)  # Swap x and y\n\n"
             "plt.ylabel('X-axis')\n"
             "plt.xlabel('Y-axis')\n"
             "plt.title('Horizontal Stem Plot')\n"
             "plt.show()"),

    ("markdown", "## 5. Plotting Multiple Data Series\n"
                 "You can plot multiple data series on the same stem plot by calling `plt.stem()` multiple times."),
    ("code", "# Generate another dataset\n"
             "y2 = np.cos(x)\n\n"
             "plt.stem(x, y, linefmt='b-', markerfmt='bo', basefmt='r-', label='sin(x)')\n"
             "plt.stem(x, y2, linefmt='g--', markerfmt='go', basefmt='r-', label='cos(x)')\n\n"
             "# Adding labels, title, and legend\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stem Plot with Multiple Data Series')\n"
             "plt.legend()\n\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `y2` is another dataset (cosine values) plotted alongside the sine values.\n"
                 "- `label` is used to add a legend to distinguish between the data series."),

    ("markdown", "## 6. Customizing the Markers and Stems Separately\n"
                 "You can further customize the appearance of the markers and stems by accessing the individual components of the stem plot."),
    ("code", "markerline, stemlines, baseline = plt.stem(x, y)\n\n"
             "# Customize markers\n"
             "markerline.set_markerfacecolor('red')\n"
             "markerline.set_markerfacecolor('red')\n"
             "markerline.set_markeredgecolor('black')\n"
             "markerline.set_markersize(10)\n\n"
             "# Customize stems\n"
             "plt.setp(stemlines, linestyle='-.', color='purple')\n\n"
             "# Customize baseline\n"
             "baseline.set_linewidth(2)\n"
             "baseline.set_color('orange')\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stem Plot with Custom Markers and Stems')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `set_markerfacecolor` changes the color inside the markers.\n"
                 "- `set_markeredgecolor` changes the color of the marker edges.\n"
                 "- `set_markersize` controls the size of the markers.\n"
                 "- `plt.setp(stemlines, ...)` customizes the stems.\n"
                 "- `set_linewidth` and `set_color` customize the baseline."),

    ("markdown", "## 7. Logarithmic Scale\n"
                 "You can use a logarithmic scale for the y-axis to better visualize data that spans several orders of magnitude."),
    ("code", "y_log = np.exp(x)  # Exponential data\n\n"
             "plt.stem(x, y_log)\n"
             "plt.yscale('log')\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Log(Y-axis)')\n"
             "plt.title('Stem Plot with Logarithmic Scale')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `yscale('log')` sets the y-axis to a logarithmic scale."),

    ("markdown", "## 8. Overlaying Stem Plots with Other Plots\n"
                 "You can overlay a stem plot with other plot types, such as line plots or scatter plots, to provide additional context."),
    ("code", "# Overlay stem plot with a line plot\n"
             "plt.plot(x, y, 'b-', label='Line Plot')  # Line plot\n"
             "plt.stem(x, y, linefmt='r--', markerfmt='ro', basefmt='g-', label='Stem Plot')\n\n"
             "# Adding labels, title, and legend\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Overlayed Line and Stem Plot')\n"
             "plt.legend()\n\n"
             "plt.show()"),

    ("markdown", "## 9. Saving the Stem Plot\n"
                 "You can save the stem plot to a file using `plt.savefig()`."),
    ("code", "plt.stem(x, y, linefmt='b-', markerfmt='bo', basefmt='r-')\n"
             "plt.title('Stem Plot to Save')\n"
             "plt.savefig('stem_plot.png', dpi=300, bbox_inches='tight')\n"
             "plt.show()"),

    ("markdown", "## 10. Stem Plot Subplots\n"
                 "You can create multiple stem plots in the same figure using `plt.subplot()`."),
    ("code", "plt.figure(figsize=(10, 5))\n\n"
             "# First subplot\n"
             "plt.subplot(1, 2, 1)\n"
             "plt.stem(x, y, linefmt='b-', markerfmt='bo', basefmt='r-')\n"
             "plt.title('Stem Plot 1')\n\n"
             "# Second subplot\n"
             "plt.subplot(1, 2, 2)\n"
             "plt.stem(x, y2, linefmt='g--', markerfmt='go', basefmt='r-')\n"
             "plt.title('Stem Plot 2')\n\n"
             "plt.tight_layout()\n"
             "plt.show()"),

    ("markdown", "## Summary:\n"
                 "The `matplotlib.pyplot.stem` function is a versatile tool for creating stem plots in Matplotlib. It offers:\n"
                 "- **Basic Plotting**: Simple stem plots to visualize discrete data points.\n"
                 "- **Customization**: Extensive control over the appearance of stems, markers, and the baseline.\n"
                 "- **Advanced Features**: Ability to plot multiple data series, use logarithmic scales, and customize components individually.\n"
                 "- **Overlaying with Other Plots**: Combine stem plots with line plots, scatter plots, or other plot types for additional context.\n"
                 "- **Subplots and Saving**: Create multiple stem plots in one figure and save them for later use.\n"
                 "Stem plots are particularly useful when you want to emphasize individual data points and their values, making them a valuable tool in various data analysis tasks. Matplotlib’s `stem` function provides the flexibility needed to create informative and visually appealing stem plots.")
]

# Add cells to the notebook
for cell_type, content in text:
    if cell_type == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(content))
    elif cell_type == "code":
        nb.cells.append(nbf.v4.new_code_cell(content))

# Save the notebook
with open("Stem_Plot.ipynb", 'w', encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook `Stem_Plot` created.")
# Out:
# Notebook `Stem_Plot` created.

# %%
import nbformat as nbf

# Create a new notebook
nb = nbf.v4.new_notebook()

# Text content to be added to the notebook
text = [
    ("markdown", "# `matplotlib.pyplot.stackplot`\n"
                 "The `matplotlib.pyplot.stackplot` function is used to create stack plots (stacked area plots) in Matplotlib. "
                 "Stack plots are a type of area chart that shows the contribution of different components to a total over time or other continuous variables. "
                 "Each component is represented as a filled area stacked on top of each other, making it easy to visualize the cumulative total as well as the individual contributions."),

    ("markdown", "## 1. Understanding Stack Plots\n"
                 "Stack plots are useful for visualizing data where you want to see both the individual contributions of components and the overall trend or total. "
                 "They are commonly used in scenarios like:\n"
                 "- Visualizing the evolution of different categories over time.\n"
                 "- Comparing the parts of a whole across multiple categories.\n"
                 "- Showing the cumulative impact of multiple series."),

    ("markdown", "## 2. Basic Usage of `stackplot` Function\n"
                 "The `stackplot` function requires at least two inputs:\n"
                 "- **x-values**: The independent variable (e.g., time or another continuous variable).\n"
                 "- **y-values**: The dependent variables, which represent the contributions of different components."),

    ("markdown", "### a. Creating a Simple Stack Plot"),
    ("code", "import matplotlib.pyplot as plt\n"
             "import numpy as np\n\n"
             "# Data\n"
             "x = np.arange(1, 6)\n"
             "y1 = [1, 2, 3, 4, 5]\n"
             "y2 = [2, 2, 2, 2, 2]\n"
             "y3 = [3, 2, 1, 2, 3]\n\n"
             "# Create a simple stack plot\n"
             "plt.stackplot(x, y1, y2, y3, labels=['Component 1', 'Component 2', 'Component 3'])\n\n"
             "# Adding labels and title\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Simple Stack Plot')\n"
             "plt.legend(loc='upper left')\n\n"
             "# Display the plot\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `x` represents the x-values, such as time points.\n"
                 "- `y1`, `y2`, `y3` represent the y-values for each component.\n"
                 "- `stackplot` creates the stack plot, stacking the areas on top of each other."),

    ("markdown", "## 3. Customizing Colors and Transparency\n"
                 "You can customize the colors of the stacked areas by passing a list of colors to the `colors` parameter. "
                 "You can also adjust the transparency of the areas using the `alpha` parameter."),

    ("code", "# Custom colors\n"
             "colors = ['skyblue', 'lightgreen', 'lightcoral']\n\n"
             "plt.stackplot(x, y1, y2, y3, colors=colors, labels=['Component 1', 'Component 2', 'Component 3'], alpha=0.8)\n\n"
             "# Adding labels and title\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stack Plot with Custom Colors and Transparency')\n"
             "plt.legend(loc='upper left')\n\n"
             "# Display the plot\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `colors` specifies the colors for each stacked area.\n"
                 "- `alpha=0.8` sets the transparency to 80%."),

    ("markdown", "## 4. Adding Baseline\n"
                 "The `baseline` parameter controls the baseline from which the stacking is calculated. It can take several options:\n"
                 "- `'zero'` (default): Stack starts from zero.\n"
                 "- `'sym'`: Symmetric stacking around a central baseline.\n"
                 "- `'wiggle'`: Minimizes the movement of individual series.\n"
                 "- `'weighted_wiggle'`: Similar to wiggle but with weights."),

    ("code", "# Baseline set to 'sym'\n"
             "plt.stackplot(x, y1, y2, y3, colors=colors, labels=['Component 1', 'Component 2', 'Component 3'], baseline='sym')\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stack Plot with Symmetric Baseline')\n"
             "plt.legend(loc='upper left')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `baseline='sym'` stacks the areas symmetrically around the central baseline."),

    ("markdown", "## 5. Stack Plot with Multiple Series\n"
                 "You can plot multiple stack plots by calling `plt.stackplot()` multiple times."),

    ("code", "# Data for another series\n"
             "y4 = [1, 1, 2, 1, 1]\n"
             "y5 = [2, 3, 1, 2, 1]\n\n"
             "# First stack plot\n"
             "plt.stackplot(x, y1, y2, y3, labels=['Component 1', 'Component 2', 'Component 3'], alpha=0.5)\n\n"
             "# Second stack plot\n"
             "plt.stackplot(x, y4, y5, labels=['Component 4', 'Component 5'], alpha=0.5)\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stack Plot with Multiple Series')\n"
             "plt.legend(loc='upper left')\n"
             "plt.show()"),

    ("markdown", "## 6. Stack Plot with Line Plots\n"
                 "You can overlay a stack plot with line plots to provide additional context, such as trends or highlights."),

    ("code", "# Data\n"
             "total = np.array(y1) + np.array(y2) + np.array(y3)\n\n"
             "# Stack plot\n"
             "plt.stackplot(x, y1, y2, y3, colors=colors, labels=['Component 1', 'Component 2', 'Component 3'], alpha=0.5)\n\n"
             "# Overlay with a line plot\n"
             "plt.plot(x, total, color='black', linestyle='--', linewidth=2, label='Total')\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stack Plot with Overlayed Line Plot')\n"
             "plt.legend(loc='upper left')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- `plt.plot()` adds a line plot representing the total sum of the components."),

    ("markdown", "## 7. Handling Missing Data\n"
                 "When data is missing (e.g., `None` or `NaN`), stack plots can handle it by either ignoring or interpolating the missing values."),

    ("code", "# Data with missing values\n"
             "y1 = [1, 2, np.nan, 4, 5]\n"
             "y2 = [2, 2, 2, np.nan, 2]\n"
             "y3 = [3, np.nan, 1, 2, 3]\n\n"
             "plt.stackplot(x, y1, y2, y3, labels=['Component 1', 'Component 2', 'Component 3'])\n\n"
             "plt.xlabel('X-axis')\n"
             "plt.ylabel('Y-axis')\n"
             "plt.title('Stack Plot with Missing Data')\n"
             "plt.legend(loc='upper left')\n"
             "plt.show()"),

    ("markdown", "In this example:\n"
                 "- Missing data is represented as `np.nan`, and Matplotlib will handle it by not plotting the corresponding sections."),

    ("markdown", "## 8. Saving the Stack Plot\n"
                 "You can save the stack plot to a file using `plt.savefig()`."),

    ("code", "plt.stackplot(x, y1, y2, y3, colors=colors, labels=['Component 1', 'Component 2', 'Component 3'])\n"
             "plt.title('Stack Plot to Save')\n"
             "plt.savefig('stack_plot.png', dpi=300, bbox_inches='tight')\n"
             "plt.show()"),

    ("markdown", "## 9. Stack Plot Subplots\n"
                 "You can create multiple stack plots in the same figure using `plt.subplot()`."),

    ("code",
    """
plt.figure(figsize=(10, 5))

# First subplot
plt.subplot(1, 2, 1)
plt.stackplot(x, y1, y2, y3, colors=colors)
plt.title('Stack Plot 1')

# Second subplot
plt.subplot(1, 2, 2)
plt.stackplot(x, y4, y5, colors=['lightblue', 'lightgreen'])
plt.title('Stack Plot 2')

plt.tight_layout()
plt.show()

    """
    ),
        ("markdown", "## 10. Interactive Stack Plots\n"
                 "In interactive environments like Jupyter Notebooks, you can make stack plots interactive by using `%matplotlib notebook`."),

    ("code",
    """
# %matplotlib notebook
plt.stackplot(x, y1, y2, y3, colors=colors, labels=['Component 1', 'Component 2', 'Component 3'])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Interactive Stack Plot')
plt.legend(loc='upper left')
plt.show()
    """
    ),
      ("markdown", "## 11. Visualizing Percentages\n"
                 "You can normalize the data to visualize the percentage contributions of each component."),

    ("code",
    """
# Normalize the data to percentages
y1_percent = y1 / np.sum([y1, y2, y3], axis=0)
y2_percent = y2 / np.sum([y1, y2, y3], axis=0)
y3_percent = y3 / np.sum([y1, y2, y3], axis=0)

plt.stackplot(x, y1_percent, y2_percent, y3_percent, colors=colors, labels=['Component 1', 'Component 2', 'Component 3'])

plt.xlabel('X-axis')
plt.ylabel('Percentage')
plt.title('Stack Plot as Percentages')
plt.legend(loc='upper left')
plt.show()

    """
    ),
    ("markdown", "## In this example:\n"
                 "- The data is normalized so that the stacked areas represent percentages, making it easier to compare relative contributions."),


("markdown", 
"""
## Summary:

The `matplotlib.pyplot.stackplot` function is a powerful tool for creating stacked area plots in Matplotlib. It offers:

- **Basic Plotting**: Simple stack plots to visualize the cumulative contributions of different components.
- **Customization**: Extensive control over colors, transparency, baselines, and overlays with other plot types.
- **Advanced Features**: Ability to handle missing data, plot multiple series, and visualize percentages.
- **Subplots and Saving**: Create multiple stack plots in one figure and save them for later use.

Stack plots are particularly useful when you want to visualize the composition and trends of different components over time or another continuous variable. Matplotlib’s stackplot function provides the flexibility needed to create informative and visually appealing stack plots.

"""
)
 ]

# Add cells to the notebook
for cell_type, content in text:
    if cell_type == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(content))
    elif cell_type == "code":
        nb.cells.append(nbf.v4.new_code_cell(content))

# Save the notebook
with open("Stack_Plot.ipynb", 'w', encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook `Stack_Plot` created.")
# Out:
# Notebook `Stack_Plot` created.

# %%
import nbformat as nbf

# Create a new notebook
nb = nbf.v4.new_notebook()

# Define the content for markdown and code cells
content = [
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "# matplotlib.pyplot.step\n"
                  "The matplotlib.pyplot.step function in Matplotlib is used to create step plots, which are a type of line plot where the data points are connected by horizontal and vertical lines, rather than straight diagonal lines. Step plots are particularly useful when you want to represent data that changes at discrete points, such as in digital signals, time series data with abrupt changes, or cumulative distributions."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 1. Understanding Step Plots\n"
                  "A step plot displays data as a series of steps rather than straight lines between points. This makes it easier to see the exact points at which changes occur. In a step plot:\n"
                  "- Horizontal Lines represent periods where the value remains constant.\n"
                  "- Vertical Lines indicate transitions between values.\n\n"
                  "Step plots are ideal for:\n"
                  "- Piecewise Constant Functions: Where the value remains constant over intervals.\n"
                  "- Cumulative Distribution Functions (CDFs): Where the function increases in steps.\n"
                  "- Digital Signals: Where signals switch between states."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 2. Basic Usage of step Function\n"
                  "The step function requires two main inputs: the x-values and the y-values. The x-values represent the points along the x-axis, and the y-values represent the height of the steps.\n\n"
                  "### a. Creating a Simple Step Plot"
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "import matplotlib.pyplot as plt\n"
                  "import numpy as np\n\n"
                  "# Data\n"
                  "x = np.arange(1, 6)\n"
                  "y = [1, 2, 3, 2, 1]\n\n"
                  "# Create a simple step plot\n"
                  "plt.step(x, y)\n\n"
                  "# Adding labels and title\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title('Simple Step Plot')\n\n"
                  "# Display the plot\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- `x` represents the x-values at which the steps occur.\n"
                  "- `y` represents the values for each step.\n"
                  "- `step` creates the step plot, connecting the data points with horizontal and vertical lines."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 3. Step Plot Orientations\n"
                  "The step function allows you to control the orientation of the steps using the `where` parameter. The `where` parameter determines where the step change occurs relative to the x-values.\n\n"
                  "### a. where='pre' (Default)"
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, where='pre')\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title(\"Step Plot with 'pre' (Default)\")\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "### b. where='post'\n"
                  "In this mode, the step changes occur after the x-value."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, where='post')\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title(\"Step Plot with 'post'\")\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "### c. where='mid'\n"
                  "In this mode, the step changes occur at the midpoint between x-values."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, where='mid')\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title(\"Step Plot with 'mid'\")\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 4. Customizing Line Styles and Colors\n"
                  "You can customize the appearance of the step plot by changing the line style, color, and marker style.\n\n"
                  "### a. Changing Line Color and Style\n"
                  "You can customize the color and style of the line using the `color` and `linestyle` parameters."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, color='red', linestyle='--')\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title('Step Plot with Custom Line Color and Style')\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- `color='red'` sets the line color to red.\n"
                  "- `linestyle='--'` sets the line style to dashed."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "### b. Adding Markers\n"
                  "You can add markers at the data points using the `marker` parameter."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, color='blue', marker='o', linestyle='-')\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title('Step Plot with Markers')\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- `marker='o'` adds circle markers at each data point."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 5. Filling Between Steps\n"
                  "You can fill the area between the steps and the x-axis using the `plt.fill_between()` function. This is useful for highlighting areas under the curve or creating step-based area plots."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, color='green', where='mid')\n"
                  "plt.fill_between(x, y, step='mid', alpha=0.4)\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title('Step Plot with Filled Area')\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- `fill_between()` fills the area under the step plot with a semi-transparent color."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 6. Step Plot with Multiple Series\n"
                  "You can plot multiple step plots on the same figure by calling `plt.step()` multiple times."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "# Another dataset\n"
                  "y2 = [2, 1, 2, 3, 2]\n\n"
                  "plt.step(x, y, where='pre', label='Series 1')\n"
                  "plt.step(x, y2, where='pre', label='Series 2', color='orange')\n\n"
                  "# Adding labels, title, and legend\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title('Step Plot with Multiple Series')\n"
                  "plt.legend()\n\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- `label` is used to add a legend to distinguish between the data series."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 7. Step Plot for Digital Signals\n"
                  "Step plots are commonly used in digital signal processing to represent changes in digital signals over time."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "# Digital signal data\n"
                  "time = np.linspace(0, 10, 11)\n"
                  "signal = [0, 1, 0, 1, 1, 0, 0, 1, 0, 1, 1]\n\n"
                  "plt.step(time, signal, where='pre', color='purple', marker='o')\n"
                  "plt.ylim(-0.5, 1.5)\n\n"
                  "plt.xlabel('Time')\n"
                  "plt.ylabel('Signal')\n"
                  "plt.title('Step Plot for Digital Signals')\n"
                  "plt.grid(True)\n\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- The step plot represents the on-off nature of a digital signal over time.\n"
                  "- `ylim(-0.5, 1.5)` is used to adjust the y-axis limits for better visualization."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 8. Logarithmic Scale\n"
                  "You can use a logarithmic scale for the x-axis or y-axis in step plots to better visualize data that spans several orders of magnitude."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "# Exponential data\n"
                  "x_log = np.logspace(0.1, 2, 10)\n"
                  "y_log = np.exp(x_log / 10)\n\n"
                  "plt.step(x_log, y_log, where='mid')\n"
                  "plt.xscale('log')\n"
                  "plt.yscale('log')\n\n"
                  "plt.xlabel('Log(X-axis)')\n"
                  "plt.ylabel('Log(Y-axis)')\n"
                  "plt.title('Step Plot with Logarithmic Scale')\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "In this example:\n"
                  "- `xscale('log')` and `yscale('log')` set the x-axis and y-axis to logarithmic scales."
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 9. Step Plot with Custom X-Intervals\n"
                  "You can create a step plot with irregular x-intervals, which is useful when data is sampled at irregular intervals."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "# Irregular intervals\n"
                  "x_irregular = [0, 1, 1.5, 3, 4.5, 6]\n"
                  "y_irregular = [1, 2, 3, 2, 4, 1]\n\n"
                  "plt.step(x_irregular, y_irregular, where='pre', color='teal', marker='s')\n\n"
                  "plt.xlabel('X-axis')\n"
                  "plt.ylabel('Y-axis')\n"
                  "plt.title('Step Plot with Irregular X-Intervals')\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 10. Saving the Step Plot\n"
                  "You can save the step plot to a file using `plt.savefig()`."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.step(x, y, where='pre', color='blue', marker='o')\n"
                  "plt.title('Step Plot to Save')\n"
                  "plt.savefig('step_plot.png', dpi=300, bbox_inches='tight')\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## 11. Step Plot Subplots\n"
                  "You can create multiple step plots in the same figure using `plt.subplot()`."
    },
    # Code cell
    {
        "cell_type": "code",
        "source": "plt.figure(figsize=(10, 5))\n\n"
                  "# First subplot\n"
                  "plt.subplot(1, 2, 1)\n"
                  "plt.step(x, y, where='pre', color='blue')\n"
                  "plt.title('Step Plot 1')\n\n"
                  "# Second subplot\n"
                  "plt.subplot(1, 2, 2)\n"
                  "plt.step(x, y2, where='post', color='red')\n"
                  "plt.title('Step Plot 2')\n\n"
                  "plt.tight_layout()\n"
                  "plt.show()"
    },
    # Markdown cell
    {
        "cell_type": "markdown",
        "source": "## Summary\n"
                  "The `matplotlib.pyplot.step` function is a versatile tool for creating step plots in Matplotlib. It offers:\n"
                  "- Basic Plotting: Simple step plots to visualize data with discrete changes.\n"
                  "- Customization: Extensive control over the appearance of lines, markers, and where the steps occur.\n"
                  "- Advanced Features: Ability to fill areas under steps, plot multiple series, handle irregular intervals, and apply logarithmic scales.\n"
                  "- Overlaying with Other Plots: Combine step plots with other plot types for additional context.\n"
                  "- Subplots and Saving: Create multiple step plots in one figure and save them for later use.\n\n"
                  "Step plots are particularly useful when you want to emphasize discrete changes in data, making them a valuable tool in fields like digital signal processing, time series analysis, and cumulative distributions. Matplotlib’s step function provides the flexibility needed to create informative and visually appealing step plots."
    }
]


# Add each cell to the notebook
for cell in content:
    if cell["cell_type"] == "markdown":
        nb.cells.append(nbf.v4.new_markdown_cell(cell["source"]))
    elif cell["cell_type"] == "code":
        nb.cells.append(nbf.v4.new_code_cell(cell["source"]))

# Save the notebook to a file
with open("Step_Plot.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("Notebook Step_Plot.ipynb created.")
# Out:
# Notebook Step_Plot.ipynb created.

# %%
import nbformat as nbf

# Create a new notebook
nb = nbf.v4.new_notebook()

# Define the content of the notebook
content = [
    # Title Markdown cell
    nbf.v4.new_markdown_cell("# Legends in Matplotlib"),

    # Introduction Markdown cell
    nbf.v4.new_markdown_cell(
        "Legends in Matplotlib are essential for making plots understandable by identifying different data series, markers, lines, and other plot elements. "
        "They provide a mapping of plot elements to their labels, helping users interpret the graphical representation of data. "
        "This discussion will cover how to create, customize, and position legends in Matplotlib, along with various advanced features and best practices."
    ),

    # Section 1: Creating a Basic Legend
    nbf.v4.new_markdown_cell("## 1. Creating a Basic Legend"),
    nbf.v4.new_markdown_cell(
        "To create a legend in Matplotlib, you typically use the `plt.legend()` function. The basic usage involves providing labels for each plot element "
        "using the `label` parameter and then calling `plt.legend()` to add the legend to the plot."
    ),
    nbf.v4.new_markdown_cell("### a. Simple Legend Example"),
    nbf.v4.new_code_cell(
        "import matplotlib.pyplot as plt\n"
        "import numpy as np\n\n"
        "# Data\n"
        "x = np.linspace(0, 10, 100)\n"
        "y1 = np.sin(x)\n"
        "y2 = np.cos(x)\n\n"
        "# Plotting the data with labels\n"
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Adding the legend\n"
        "plt.legend()\n\n"
        "# Adding labels and title\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Basic Legend Example')\n\n"
        "# Display the plot\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `label='Sine Wave'` and `label='Cosine Wave'` provide labels for the sine and cosine plots.\n"
        "- `plt.legend()` adds the legend to the plot."
    ),

    # Section 2: Positioning the Legend
    nbf.v4.new_markdown_cell("## 2. Positioning the Legend"),
    nbf.v4.new_markdown_cell(
        "By default, Matplotlib places the legend in the “best” location, which avoids overlapping with plot elements. However, you can manually specify the "
        "legend's location using the `loc` parameter."
    ),
    nbf.v4.new_markdown_cell("### a. Specifying Legend Location"),
    nbf.v4.new_code_cell(
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Specifying the legend location\n"
        "plt.legend(loc='upper right')\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend Positioned in Upper Right')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "Common values for the `loc` parameter include:\n"
        "- `'best'` (default): Automatically positions the legend to avoid overlapping with plot elements.\n"
        "- `'upper right'`, `'upper left'`, `'lower right'`, `'lower left'`: Positions the legend in the specified corner.\n"
        "- `'center'`, `'center left'`, `'center right'`: Positions the legend in the center or along the center edges.\n"
        "- `'upper center'`, `'lower center'`: Positions the legend at the top or bottom center."
    ),
    nbf.v4.new_markdown_cell("### b. Using Numeric Coordinates"),
    nbf.v4.new_code_cell(
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Numeric coordinates (x, y) where (0,0) is lower left and (1,1) is upper right\n"
        "plt.legend(loc=(0.1, 0.8))\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend Positioned Using Numeric Coordinates')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `loc=(0.1, 0.8)` positions the legend 10% from the left and 80% from the bottom of the plot."
    ),

    # Section 3: Customizing Legend Appearance
    nbf.v4.new_markdown_cell("## 3. Customizing Legend Appearance"),
    nbf.v4.new_markdown_cell(
        "You can customize various aspects of the legend, such as its font size, color, and frame, using parameters like `fontsize`, `frameon`, `fancybox`, `shadow`, and more."
    ),
    nbf.v4.new_markdown_cell("### a. Changing Font Size"),
    nbf.v4.new_code_cell(
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Changing the font size of the legend\n"
        "plt.legend(fontsize='large')\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend with Large Font Size')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `fontsize='large'` sets the legend’s font size to large. You can also use specific point sizes or values like `'small'`, `'medium'`, etc."
    ),
    

# Section 4: Legend for Multiple Plots

    nbf.v4.new_markdown_cell("## 4. Legend for Multiple Plots"),
    nbf.v4.new_markdown_cell(
        "When dealing with multiple plots, you can use the legend to distinguish between the different data series."
    ),
    nbf.v4.new_markdown_cell("### a. Multiple Lines with Different Markers"),
    nbf.v4.new_code_cell(
        "# Different datasets\n"
        "y1 = np.sin(x)\n"
        "y2 = np.cos(x)\n"
        "y3 = np.sin(x) + np.cos(x)\n\n"
        "# Plotting multiple lines with different markers\n"
        "plt.plot(x, y1, label='Sine Wave', marker='o')\n"
        "plt.plot(x, y2, label='Cosine Wave', marker='s')\n"
        "plt.plot(x, y3, label='Sine + Cosine', marker='^')\n\n"
        "plt.legend()\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend for Multiple Lines with Different Markers')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- Each plot line has a different marker ('o' for circles, 's' for squares, and '^' for triangles), and the legend reflects these differences."
    ),


# Section 5: Legend Outside the Plot

    nbf.v4.new_markdown_cell("## 5. Legend Outside the Plot"),
    nbf.v4.new_markdown_cell(
        "Sometimes, it’s useful to place the legend outside the plot area, especially when the legend might overlap with data points."
    ),
    nbf.v4.new_code_cell(
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Placing the legend outside the plot\n"
        "plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend Positioned Outside the Plot')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `bbox_to_anchor=(1, 0.5)` positions the legend outside the plot area to the right.\n"
        "- `loc='center left'` aligns the legend to the center left of the bounding box."
    ),


# Section 6: Handling Large Legends
    nbf.v4.new_markdown_cell("## 6. Handling Large Legends"),
    nbf.v4.new_markdown_cell(
        "If your plot has many elements, the legend can become crowded. You can manage this by adjusting the legend’s columns, spacing, and alignment."
    ),
    nbf.v4.new_markdown_cell("### a. Multiple Columns in Legend"),
    nbf.v4.new_code_cell(
        "# Creating multiple lines\n"
        "for i in range(1, 6):\n"
        "    plt.plot(x, np.sin(x + i), label=f'Wave {i}')\n\n"
        "# Creating a legend with multiple columns\n"
        "plt.legend(ncol=2)\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend with Multiple Columns')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `ncol=2` arranges the legend into two columns."
    ),
    nbf.v4.new_markdown_cell("### b. Adjusting Spacing Between Legend Entries"),
    nbf.v4.new_code_cell(
        "# Creating multiple lines\n"
        "for i in range(1, 6):\n"
        "    plt.plot(x, np.sin(x + i), label=f'Wave {i}')\n\n"
        "# Adjusting spacing in the legend\n"
        "plt.legend(labelspacing=1.2, columnspacing=1.0)\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend with Adjusted Spacing')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `labelspacing=1.2` controls the vertical space between legend entries.\n"
        "- `columnspacing=1.0` controls the horizontal space between columns in a multi-column legend."
    ),

# Section 7: Legend for Specific Plots

    nbf.v4.new_markdown_cell("## 7. Legend for Specific Plots"),
    nbf.v4.new_markdown_cell(
        "Sometimes, you might want to create a legend that only includes specific plot elements. You can achieve this by selectively labeling only the desired elements."
    ),
    nbf.v4.new_code_cell(
        "# Different datasets\n"
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2)  # No label for cosine wave\n\n"
        "# Create a legend for only the sine wave\n"
        "plt.legend()\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend for Specific Plot')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- Only the sine wave is labeled, so the legend only includes the sine wave entry."
    ),


# Section 8: Custom Legend Handles
    nbf.v4.new_markdown_cell("## 8. Custom Legend Handles"),
    nbf.v4.new_markdown_cell(
        "You can create custom legend entries using `Line2D` or `Patch` objects to represent custom elements in the legend."
    ),
    nbf.v4.new_code_cell(
        "from matplotlib.lines import Line2D\n\n"
        "# Custom legend handles\n"
        "custom_lines = [Line2D([0], [0], color='blue', lw=2, linestyle='--'),\n"
        "                Line2D([0], [0], color='orange', lw=2, linestyle='-')]\n\n"
        "# Plotting the data\n"
        "plt.plot(x, y1, 'b--')\n"
        "plt.plot(x, y2, 'orange')\n\n"
        "# Custom legend\n"
        "plt.legend(custom_lines, ['Dashed Blue', 'Solid Orange'])\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Custom Legend Handles')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `Line2D` objects are used to create custom legend entries that represent specific styles not directly linked to plot elements."
    ),

# Section 9: Interactive Legends
    nbf.v4.new_markdown_cell("## 9. Interactive Legends"),
    nbf.v4.new_markdown_cell(
        "In interactive environments like Jupyter Notebooks, you can create legends that can be toggled on and off, making it easier to explore different parts of the plot."
    ),
    nbf.v4.new_code_cell(
        "%matplotlib notebook\n\n"
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "plt.legend(loc='best')\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Interactive Legend Example')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `%matplotlib notebook` enables interactive plotting in Jupyter, allowing you to toggle the legend elements on and off by clicking."
    ),

# Section 10: Saving a Plot with Legends

    nbf.v4.new_markdown_cell("## 10. Saving a Plot with Legends"),
    nbf.v4.new_markdown_cell(
        "When saving plots that include legends, you may need to ensure that the legend doesn’t get cut off. You can adjust the layout to accommodate the legend."
    ),
    nbf.v4.new_code_cell(
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "plt.legend(loc='best')\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Plot with Legend to Save')\n\n"
        "# Save the plot, ensuring that the legend is not cut off\n"
        "plt.savefig('plot_with_legend.png', bbox_inches='tight')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `bbox_inches='tight'` ensures that the legend is fully included when saving the plot."
    ),

# Conclusion

    nbf.v4.new_markdown_cell("# Conclusion"),
    nbf.v4.new_markdown_cell(
        "Legends are a crucial part of any plot, providing clarity and context to the data being presented. "
        "By understanding how to create, customize, and position legends, you can enhance the readability and professionalism of your visualizations."
    )
    
]

# Add content to the notebook
nb['cells'].extend(content)

# Save the notebook to a file
with open("Legends.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)
    
print("Notebook `Legends.ipynb` created.")
# Out:
# Notebook `Legends.ipynb` created.

# %% [markdown]
# ### Some more way to make .ipynb file

# %%
import nbformat as nbf
# Create a new notebook
nb = nbf.v4.new_notebook()

# Define the content of the notebook
content = [
    # Title Markdown cell
    nbf.v4.new_markdown_cell("# Legends in Matplotlib"),

    # Introduction Markdown cell
    nbf.v4.new_markdown_cell(
        "Legends in Matplotlib are essential for making plots understandable by identifying different data series, markers, lines, and other plot elements. "
        "They provide a mapping of plot elements to their labels, helping users interpret the graphical representation of data. "
        "This discussion will cover how to create, customize, and position legends in Matplotlib, along with various advanced features and best practices."
    ),

    # Section 1: Creating a Basic Legend
    nbf.v4.new_markdown_cell("## 1. Creating a Basic Legend"),
    
    nbf.v4.new_markdown_cell("### a. Simple Legend Example"),
    nbf.v4.new_code_cell(
        "import matplotlib.pyplot as plt\n"
        "import numpy as np\n\n"
        "# Data\n"
        "x = np.linspace(0, 10, 100)\n"
        "y1 = np.sin(x)\n"
        "y2 = np.cos(x)\n\n"
        "# Plotting the data with labels\n"
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Adding the legend\n"
        "plt.legend()\n\n"
        "# Adding labels and title\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Basic Legend Example')\n\n"
        "# Display the plot\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `label='Sine Wave'` and `label='Cosine Wave'` provide labels for the sine and cosine plots.\n"
        "- `plt.legend()` adds the legend to the plot."
    )

]

# Add content to the notebook
nb['cells'].extend(content)


# Section 2: Legend for Multiple Plots
nb['cells'].extend([
    nbf.v4.new_markdown_cell("## 4. Legend for Multiple Plots"),
    nbf.v4.new_markdown_cell(
        "When dealing with multiple plots, you can use the legend to distinguish between the different data series."
    ),
    nbf.v4.new_markdown_cell("### a. Multiple Lines with Different Markers"),
    nbf.v4.new_code_cell(
        "# Different datasets\n"
        "y1 = np.sin(x)\n"
        "y2 = np.cos(x)\n"
        "y3 = np.sin(x) + np.cos(x)\n\n"
        "# Plotting multiple lines with different markers\n"
        "plt.plot(x, y1, label='Sine Wave', marker='o')\n"
        "plt.plot(x, y2, label='Cosine Wave', marker='s')\n"
        "plt.plot(x, y3, label='Sine + Cosine', marker='^')\n\n"
        "plt.legend()\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend for Multiple Lines with Different Markers')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- Each plot line has a different marker ('o' for circles, 's' for squares, and '^' for triangles), and the legend reflects these differences."
    )
])

# Section 3: Legend Outside the Plot
nb['cells'].extend([
    nbf.v4.new_markdown_cell("## 5. Legend Outside the Plot"),
    nbf.v4.new_markdown_cell(
        "Sometimes, it’s useful to place the legend outside the plot area, especially when the legend might overlap with data points."
    ),
    nbf.v4.new_code_cell(
        "plt.plot(x, y1, label='Sine Wave')\n"
        "plt.plot(x, y2, label='Cosine Wave')\n\n"
        "# Placing the legend outside the plot\n"
        "plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))\n\n"
        "plt.xlabel('X-axis')\n"
        "plt.ylabel('Y-axis')\n"
        "plt.title('Legend Positioned Outside the Plot')\n"
        "plt.show()"
    ),
    nbf.v4.new_markdown_cell(
        "In this example:\n"
        "- `bbox_to_anchor=(1, 0.5)` positions the legend outside the plot area to the right.\n"
        "- `loc='center left'` aligns the legend to the center left of the bounding box."
    )
])


# Save the completed notebook to a file
with open("Testpage_legends_in_matplotlib.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)
print("Notebook `Test ` is successful.")
# Out:
# Notebook `Test ` is successful.

# %%
import nbformat as nbf

# Create a new notebook object
nb = nbf.v4.new_notebook()

# Title cell
nb['cells'].append(nbf.v4.new_markdown_cell("# Subplots in Matplotlib"))

# Introduction
nb['cells'].append(nbf.v4.new_markdown_cell(
    "Subplots in Matplotlib allow you to create multiple plots within a single figure, enabling you to visualize different aspects of your data side by side. "
    "This is particularly useful when you want to compare different datasets, plot different views of the same data, or create complex layouts of plots. "
    "Subplots are versatile and can be customized in various ways, including adjusting their layout, sharing axes, and adding annotations."
))

# Basic Usage of Subplots
nb['cells'].append(nbf.v4.new_markdown_cell("## 1. Basic Usage of Subplots"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "The simplest way to create subplots is using the `plt.subplot()` function, which allows you to create a grid of plots within a single figure."
))

# Creating a 2x2 Grid of Subplots
nb['cells'].append(nbf.v4.new_markdown_cell("### a. Creating a 2x2 Grid of Subplots"))
nb['cells'].append(nbf.v4.new_code_cell(
    "import matplotlib.pyplot as plt\n"
    "import numpy as np\n"
    "\n"
    "# Data\n"
    "x = np.linspace(0, 10, 100)\n"
    "y1 = np.sin(x)\n"
    "y2 = np.cos(x)\n"
    "y3 = np.tan(x)\n"
    "y4 = np.exp(x)\n"
    "\n"
    "# Create a 2x2 grid of subplots\n"
    "plt.figure(figsize=(10, 8))\n"
    "\n"
    "plt.subplot(2, 2, 1)  # (rows, columns, index)\n"
    "plt.plot(x, y1)\n"
    "plt.title('Sine Wave')\n"
    "\n"
    "plt.subplot(2, 2, 2)\n"
    "plt.plot(x, y2)\n"
    "plt.title('Cosine Wave')\n"
    "\n"
    "plt.subplot(2, 2, 3)\n"
    "plt.plot(x, y3)\n"
    "plt.title('Tangent Wave')\n"
    "\n"
    "plt.subplot(2, 2, 4)\n"
    "plt.plot(x, y4)\n"
    "plt.title('Exponential')\n"
    "\n"
    "# Adjust layout to prevent overlapping\n"
    "plt.tight_layout()\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `plt.subplot(2, 2, 1)` creates the first subplot in a 2x2 grid.\n"
    "- The `tight_layout()` function is used to automatically adjust subplot parameters to give specified padding."
))

# Using plt.subplots() for More Control
nb['cells'].append(nbf.v4.new_markdown_cell("## 2. Using `plt.subplots()` for More Control"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "The `plt.subplots()` function is more powerful and flexible than `plt.subplot()`. It returns a figure object and an array of axes objects, allowing you to control the layout and appearance of subplots more precisely."
))

# Creating a 2x2 Grid with plt.subplots()
nb['cells'].append(nbf.v4.new_markdown_cell("### a. Creating a 2x2 Grid with plt.subplots()"))
nb['cells'].append(nbf.v4.new_code_cell(
    "# Create a 2x2 grid of subplots\n"
    "fig, axes = plt.subplots(2, 2, figsize=(10, 8))\n"
    "\n"
    "# Plotting data on each subplot\n"
    "axes[0, 0].plot(x, y1)\n"
    "axes[0, 0].set_title('Sine Wave')\n"
    "\n"
    "axes[0, 1].plot(x, y2)\n"
    "axes[0, 1].set_title('Cosine Wave')\n"
    "\n"
    "axes[1, 0].plot(x, y3)\n"
    "axes[1, 0].set_title('Tangent Wave')\n"
    "\n"
    "axes[1, 1].plot(x, y4)\n"
    "axes[1, 1].set_title('Exponential')\n"
    "\n"
    "# Adjust layout\n"
    "plt.tight_layout()\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `fig, axes = plt.subplots(2, 2)` creates a 2x2 grid of subplots, with `axes` being an array of Axes objects.\n"
    "- `axes[i, j]` refers to each subplot, allowing you to easily customize and plot data on each one."
))

# Customizing Subplot Layouts
nb['cells'].append(nbf.v4.new_markdown_cell("## 3. Customizing Subplot Layouts"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "You can customize the layout of subplots to fit your specific needs, including creating grids of different sizes, sharing axes, and adjusting spacing."
))

# Creating Subplots with Different Sizes
nb['cells'].append(nbf.v4.new_markdown_cell("### a. Creating Subplots with Different Sizes"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "You can create subplots with different sizes by specifying the grid size and the positions of each subplot."
))
nb['cells'].append(nbf.v4.new_code_cell(
    "# Create a figure with subplots of different sizes\n"
    "fig = plt.figure(figsize=(8, 6))\n"
    "\n"
    "# Main plot spanning two columns\n"
    "ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)\n"
    "ax1.plot(x, y1)\n"
    "ax1.set_title('Main Plot')\n"
    "\n"
    "# Small subplot\n"
    "ax2 = plt.subplot2grid((3, 3), (1, 0))\n"
    "ax2.plot(x, y2)\n"
    "ax2.set_title('Small Subplot 1')\n"
    "\n"
    "# Small subplot\n"
    "ax3 = plt.subplot2grid((3, 3), (1, 1))\n"
    "ax3.plot(x, y3)\n"
    "ax3.set_title('Small Subplot 2')\n"
    "\n"
    "# Small subplot spanning two columns\n"
    "ax4 = plt.subplot2grid((3, 3), (1, 2), rowspan=2)\n"
    "ax4.plot(x, y4)\n"
    "ax4.set_title('Tall Subplot')\n"
    "\n"
    "# Adjust layout\n"
    "plt.tight_layout()\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `plt.subplot2grid((3, 3), (0, 0), colspan=3)` creates a subplot that spans three columns in a 3x3 grid.\n"
    "- `plt.subplot2grid((3, 3), (1, 2), rowspan=2)` creates a subplot that spans two rows."
))

# Sharing Axes Between Subplots
nb['cells'].append(nbf.v4.new_markdown_cell("### b. Sharing Axes Between Subplots"))
nb['cells'].append(nbf.v4.new_markdown_cell("Sharing axes between subplots ensures that the subplots use the same scale, which is particularly useful for comparison."))
nb['cells'].append(nbf.v4.new_code_cell(
    "# Create subplots with shared x-axis\n"
    "fig, axes = plt.subplots(2, 1, sharex=True, figsize=(8, 6))\n"
    "\n"
    "axes[0].plot(x, y1)\n"
    "axes[0].set_title('Sine Wave')\n"
    "\n"
    "axes[1].plot(x, y2)\n"
    "axes[1].set_title('Cosine Wave')\n"
    "\n"
    "# Adjust layout\n"
    "plt.tight_layout()\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `sharex=True` ensures that the x-axis is shared between the subplots.\n"
    "You can also share the y-axis using `sharey=True`."
))

# Adjusting Subplot Spacing
nb['cells'].append(nbf.v4.new_markdown_cell("## 4. Adjusting Subplot Spacing"))

nb['cells'].append(nbf.v4.new_markdown_cell(
    "Matplotlib provides several methods to adjust the spacing between subplots, ensuring that they are not too close together or too far apart."
))

# Adjusting Spacing with subplots_adjust()
nb['cells'].append(nbf.v4.new_markdown_cell(
"""
### a. Using `plt.tight_layout()`
The `tight_layout()` function automatically adjusts subplot parameters to ensure that subplots fit within the figure area without overlapping.
"""
))

nb['cells'].append(nbf.v4.new_code_cell(
"""
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plotting data on each subplot
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Sine Wave')

axes[0, 1].plot(x, y2)
axes[0, 1].set_title('Cosine Wave')

axes[1, 0].plot(x, y3)
axes[1, 0].set_title('Tangent Wave')

axes[1, 1].plot(x, y4)
axes[1, 1].set_title('Exponential')

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

"""
))

# Creating Complex Layouts with GridSpec
nb['cells'].append(nbf.v4.new_markdown_cell(
"""
#### b. Using plt.subplots_adjust()
The `subplots_adjust()` function gives you fine control over the spacing between subplots.
"""
))

nb['cells'].append(nbf.v4.new_code_cell(
"""
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plotting data on each subplot
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Sine Wave')

axes[0, 1].plot(x, y2)
axes[0, 1].set_title('Cosine Wave')

axes[1, 0].plot(x, y3)
axes[1, 0].set_title('Tangent Wave')

axes[1, 1].plot(x, y4)
axes[1, 1].set_title('Exponential')

# Adjust spacing between subplots
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1, wspace=0.3, hspace=0.4)

# Display the plot
plt.show()

"""
))
nb['cells'].append(nbf.v4.new_markdown_cell(
"""
In this example:
- `wspace` and `hspace` control the amount of width and height reserved for space between subplots.
- `left`, `right`, `top`, `bottom` adjust the margins around the subplots.
"""    
))

# Creating Complex Layouts with GridSpec
# Adjusting Subplot Spacing
nb['cells'].append(nbf.v4.new_markdown_cell("## 4. Adjusting Subplot Spacing"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "Matplotlib provides several methods to adjust the spacing between subplots, ensuring that they are not too close together or too far apart."
))

# Adjusting Spacing with subplots_adjust()
nb['cells'].append(nbf.v4.new_markdown_cell("### a. Adjusting Spacing with subplots_adjust()"))
nb['cells'].append(nbf.v4.new_code_cell(
    "# Create subplots with adjusted spacing\n"
    "fig, axes = plt.subplots(2, 2, figsize=(8, 6))\n"
    "\n"
    "axes[0, 0].plot(x, y1)\n"
    "axes[0, 0].set_title('Sine Wave')\n"
    "\n"
    "axes[0, 1].plot(x, y2)\n"
    "axes[0, 1].set_title('Cosine Wave')\n"
    "\n"
    "axes[1, 0].plot(x, y3)\n"
    "axes[1, 0].set_title('Tangent Wave')\n"
    "\n"
    "axes[1, 1].plot(x, y4)\n"
    "axes[1, 1].set_title('Exponential')\n"
    "\n"
    "# Adjust spacing between subplots\n"
    "plt.subplots_adjust(wspace=0.3, hspace=0.5)\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `plt.subplots_adjust(wspace=0.3, hspace=0.5)` adjusts the width and height spacing between the subplots."
))
nb['cells'].append(nbf.v4.new_markdown_cell("### b. Creating Complex Layouts with GridSpec"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "Matplotlib's `GridSpec` is a powerful tool for creating complex subplot layouts. It allows you to create subplots that span multiple rows or columns with more control over spacing."
))
nb['cells'].append(nbf.v4.new_code_cell(
    "import matplotlib.gridspec as gridspec\n"
    "\n"
    "# Create a GridSpec layout\n"
    "fig = plt.figure(figsize=(10, 8))\n"
    "gs = gridspec.GridSpec(3, 3)\n"
    "\n"
    "# Main plot spanning two columns\n"
    "ax1 = fig.add_subplot(gs[0, :2])\n"
    "ax1.plot(x, y1)\n"
    "ax1.set_title('Main Plot')\n"
    "\n"
    "# Tall subplot\n"
    "ax2 = fig.add_subplot(gs[1:, -1])\n"
    "ax2.plot(x, y2)\n"
    "ax2.set_title('Tall Subplot')\n"
    "\n"
    "# Small subplots\n"
    "ax3 = fig.add_subplot(gs[1, :-1])\n"
    "ax3.plot(x, y3)\n"
    "ax3.set_title('Small Subplot 1')\n"
    "\n"
    "ax4 = fig.add_subplot(gs[2, :-1])\n"
    "ax4.plot(x, y4)\n"
    "ax4.set_title('Small Subplot 2')\n"
    "\n"
    "# Adjust layout\n"
    "plt.tight_layout()\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `GridSpec(3, 3)` creates a 3x3 grid layout.\n"
    "- `fig.add_subplot(gs[0, :2])` creates a subplot that spans the first row and two columns."
))

# Adding Annotations to Subplots
nb['cells'].append(nbf.v4.new_markdown_cell("## 5. Adding Annotations to Subplots"))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "Annotations can be added to subplots to highlight specific data points, add labels, or create custom notes within your plots."
))

# Adding Annotations Example
nb['cells'].append(nbf.v4.new_markdown_cell("### a. Adding Annotations Example"))
nb['cells'].append(nbf.v4.new_code_cell(
    "# Create subplots\n"
    "fig, axes = plt.subplots(2, 2, figsize=(10, 8))\n"
    "\n"
    "# Sine wave with annotation\n"
    "axes[0, 0].plot(x, y1)\n"
    "axes[0, 0].set_title('Sine Wave')\n"
    "axes[0, 0].annotate('Local Max', xy=(1.57, 1), xytext=(3, 1.5),\n"
    "                 arrowprops=dict(facecolor='black', arrowstyle='->'))\n"
    "\n"
    "# Cosine wave with annotation\n"
    "axes[0, 1].plot(x, y2)\n"
    "axes[0, 1].set_title('Cosine Wave')\n"
    "axes[0, 1].annotate('Local Min', xy=(4.71, -1), xytext=(6, -1.5),\n"
    "                 arrowprops=dict(facecolor='blue', arrowstyle='->'))\n"
    "\n"
    "# Tangent wave without annotation\n"
    "axes[1, 0].plot(x, y3)\n"
    "axes[1, 0].set_title('Tangent Wave')\n"
    "\n"
    "# Exponential with annotation\n"
    "axes[1, 1].plot(x, y4)\n"
    "axes[1, 1].set_title('Exponential')\n"
    "axes[1, 1].annotate('Steep Rise', xy=(2, np.exp(2)), xytext=(3, 50),\n"
    "                 arrowprops=dict(facecolor='red', arrowstyle='->'))\n"
    "\n"
    "# Adjust layout\n"
    "plt.tight_layout()\n"
    "\n"
    "# Display the plot\n"
    "plt.show()"
))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "In this example:\n"
    "- `annotate()` is used to add annotations to specific points on the plot.\n"
    "- The `arrowprops` parameter customizes the appearance of the annotation arrow."
))



nb['cells'].append(nbf.v4.new_markdown_cell(
"""
## 5. Adding Titles and Labels to Subplots
You can add titles and labels to each subplot individually, as well as a common title or label for the entire figure.
"""

))
nb['cells'].append(nbf.v4.new_markdown_cell(
    "Annotations can be added to subplots to highlight specific data points, add labels, or create custom notes within your plots."
))

nb['cells'].append(nbf.v4.new_markdown_cell(
"""
### a. Individual Titles and Labels
Each subplot can have its own title and axis labels.
"""
))
nb['cells'].append(nbf.v4.new_code_cell(
"""
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plotting data with titles and labels
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Sine Wave')
axes[0, 0].set_xlabel('X')
axes[0, 0].set_ylabel('Y')

axes[0, 1].plot(x, y2)
axes[0, 1].set_title('Cosine Wave')
axes[0, 1].set_xlabel('X')
axes[0, 1].set_ylabel('Y')

axes[1, 0].plot(x, y3)
axes[1, 0].set_title('Tangent Wave')
axes[1, 0].set_xlabel('X')
axes[1, 0].set_ylabel('Y')

axes[1, 1].plot(x, y4)
axes[1, 1].set_title('Exponential')
axes[1, 1].set_xlabel('X')
axes[1, 1].set_ylabel('Y')

plt.tight_layout()

# Display the plot
plt.show()

"""
))


nb['cells'].append(nbf.v4.new_markdown_cell(
"""
### b. Adding a Common Title
You can add a common title for all subplots using `fig.suptitle()`.
"""
))

nb['cells'].append(nbf.v4.new_code_cell(
"""
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plotting data with individual titles
axes[0, 0].plot(x, y1)
axes[0, 1].plot(x, y2)
axes[1, 0].plot(x, y3)
axes[1, 1].plot(x, y4)

# Adding a common title
fig.suptitle('Common Title for All Subplots', fontsize=16)

plt.tight_layout(rect=[0, 0, 1, 0.96])

# Display the plot
plt.show()

"""
))

nb['cells'].append(nbf.v4.new_markdown_cell(
"""
In this example:
- `fig.suptitle()` adds a title for the entire figure.
- `tight_layout(rect=[0, 0, 1, 0.96])` ensures that the subplots don’t overlap with the common title.
"""
))

nb['cells'].append(nbf.v4.new_code_cell(
    "# Create subplots\n"
    "fig, axes = plt.subplots(2, 2, figsize=(10, 8))\n"
    "\n"
    "# Sine wave with annotation\n"
    "axes[0, 0].plot(x, y1)\n"
    "axes[0, 0].set_title('Sine Wave')\n"
    "axes[0, 0].annotate('Local Max', xy=(1.57, 1), xytext=(3, 1.5),\n"
    "                 arrowprops=dict(facecolor='black', arrowstyle='->'))\n"
    "\n"
    "# Cosine wave with annotation\n"
    "axes[0, 1].plot(x, y2)\n"
    "axes[0, 1].set_title('Cosine Wave')\n"
    "axes[0, 1].annotate('Local Min', xy=(4.71, -1), xytext=(6, -1.5),\n"
    "                 arrowprops=dict(facecolor='blue', arrowstyle='->'))\n"
    "\n"
    "# Tangent wave without annotation\n"
    "axes[1, 0].plot(x, y3)\n"
    "axes[1, 0].set_title('Tangent Wave')\n"
    "\n"
    "# Exponential with annotation\n"
    "axes[1, 1].plot(x, y4)\n"
    "axes[1, 1].set_title('Exponential')\n"
    "axes[1, 1].annotate('Steep Rise', xy=(2, np.exp(2)), xytext=(3, 50),\n"
    "                 arrowprops=dict(facecolor='red', arrowstyle='->'))\n"
    "\n"
    "# Adjust layout\n"
    "plt.tight_layout()\n"
    "\n"
    
))

nb['cells'].append(nbf.v4.new_markdown_cell(
"""
## 6. Inserting Inset Plots
An inset plot is a small plot within a larger plot, useful for zooming in on a particular area of interest.
"""
))

nb['cells'].append(nbf.v4.new_code_cell(
"""
# Create main plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, y1)
ax.set_title('Main Plot with Inset')

# Create an inset plot
inset_ax = fig.add_axes([0.5, 0.5, 0.4, 0.4])  # [left, bottom, width, height]
inset_ax.plot(x, y2)
inset_ax.set_title('Inset Plot')

# Display the plot
plt.show()

"""
))
nb['cells'].append(nbf.v4.new_markdown_cell(
"""
In this example:
- `fig.add_axes([0.5, 0.5, 0.4, 0.4])` adds an inset plot to the main figure.
"""
))

nb['cells'].append(nbf.v4.new_markdown_cell(
"""
## 7. Saving a Figure with Subplots
When saving a figure with subplots, it’s important to ensure that everything fits well within the saved image.
"""
))

nb['cells'].append(nbf.v4.new_code_cell(
"""
saved image.
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plotting data
axes[0, 0].plot(x, y1)
axes[0, 1].plot(x, y2)
axes[1, 0].plot(x, y3)
axes[1, 1].plot(x, y4)

# Adjust layout and add a common title
fig.suptitle('Figure with Subplots', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Save the figure
plt.savefig('figure_with_subplots.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
"""
))
nb['cells'].append(nbf.v4.new_markdown_cell(
"""
In this example:
- `bbox_inches='tight'` ensures that all elements, including titles and labels, are included in the saved image.

"""
))

nb['cells'].append(nbf.v4.new_markdown_cell(
"""
## Summary:
Subplots in Matplotlib are a powerful feature for visualizing multiple plots within a single figure. Key aspects include:

- **Basic Usage**: Creating simple grids of subplots using plt.subplot() or plt.subplots().
- **Layout Customization**: Adjusting the layout of subplots, including sharing axes, controlling spacing, and creating subplots of different sizes.
- **Titles and Labels**: Adding individual titles and labels, as well as common titles for the entire figure.
- **Inset Plots**: Inserting small plots within larger plots for detailed views.
- **Saving Figures**: Ensuring that all elements are included when saving figures with subplots.

By mastering subplots, you can create complex, informative, and visually appealing visualizations that effectively communicate your data.

"""
))
# Save the notebook to a file
with open("Subplots.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)
print("Notebook `Subplots.ipynb` created.")
# Out:
# Notebook `Subplots.ipynb` created.
